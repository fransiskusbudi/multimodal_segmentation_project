# %%
# Cell 1: Install libraries if needed
# !pip install nibabel pandas

# Cell 2: Import libraries
import os
import nibabel as nib
import pandas as pd

# Cell 3: Define your dataset directory
# Adjust this to your dataset directory
data_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/"  # Replace with your dataset path

# Cell 4: Collect all NIfTI files
nifti_files = [f for f in os.listdir(data_dir) if f.endswith('.nii') or f.endswith('.nii.gz')]

# Cell 5: Function to inspect shape and spacing
def inspect_nifti(file_path):
    nii = nib.load(file_path)
    shape = nii.shape
    spacing = nii.header.get_zooms()
    affine = nii.affine
    return shape, spacing, affine

# Cell 6: Loop over all files and collect results
results = []

for file in sorted(nifti_files):
    file_path = os.path.join(data_dir, file)
    shape, spacing, affine = inspect_nifti(file_path)
    results.append({
        "File": file,
        "Shape": shape,
        "Spacing (X,Y,Z)": spacing,
        "Affine": affine
    })

# Cell 7: Display results in a DataFrame
df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)  # Show all rows
print(df)

# Optional: Save to CSV
# df.to_csv("slice_shape_spacing_summary.csv", index=False)
# Out:
#                  File            Shape  Spacing (X,Y,Z)  \
# 0    amos_0001.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 1    amos_0004.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 2    amos_0005.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 3    amos_0006.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 4    amos_0007.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 5    amos_0009.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 6    amos_0010.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 7    amos_0011.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 8    amos_0014.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 9    amos_0015.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 10   amos_0016.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 11   amos_0017.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 12   amos_0019.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 13   amos_0021.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 14   amos_0023.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 15   amos_0024.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 16   amos_0025.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 17   amos_0027.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 18   amos_0030.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 19   amos_0033.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 20   amos_0035.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 21   amos_0036.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 22   amos_0038.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 23   amos_0042.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 24   amos_0043.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 25   amos_0044.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 26   amos_0045.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 27   amos_0047.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 28   amos_0048.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 29   amos_0049.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 30   amos_0050.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 31   amos_0052.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 32   amos_0054.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 33   amos_0057.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 34   amos_0058.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 35   amos_0059.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 36   amos_0060.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 37   amos_0064.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 38   amos_0066.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 39   amos_0067.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 40   amos_0069.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 41   amos_0071.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 42   amos_0072.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 43   amos_0075.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 44   amos_0076.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 45   amos_0077.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 46   amos_0078.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 47   amos_0079.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 48   amos_0081.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 49   amos_0083.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 50   amos_0084.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 51   amos_0086.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 52   amos_0088.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 53   amos_0089.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 54   amos_0092.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 55   amos_0094.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 56   amos_0097.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 57   amos_0098.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 58   amos_0099.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 59   amos_0102.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 60   amos_0103.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 61   amos_0104.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 62   amos_0105.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 63   amos_0109.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 64   amos_0110.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 65   amos_0111.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 66   amos_0113.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 67   amos_0115.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 68   amos_0116.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 69   amos_0118.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 70   amos_0119.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 71   amos_0121.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 72   amos_0124.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 73   amos_0125.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 74   amos_0126.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 75   amos_0127.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 76   amos_0129.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 77   amos_0131.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 78   amos_0133.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 79   amos_0134.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 80   amos_0135.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 81   amos_0137.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 82   amos_0138.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 83   amos_0141.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 84   amos_0142.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 85   amos_0143.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 86   amos_0147.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 87   amos_0149.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 88   amos_0152.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 89   amos_0153.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 90   amos_0154.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 91   amos_0156.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 92   amos_0158.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 93   amos_0159.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 94   amos_0160.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 95   amos_0161.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 96   amos_0162.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 97   amos_0166.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 98   amos_0170.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 99   amos_0171.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 100  amos_0172.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 101  amos_0173.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 102  amos_0175.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 103  amos_0177.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 104  amos_0179.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 105  amos_0180.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 106  amos_0181.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 107  amos_0184.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 108  amos_0185.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 109  amos_0186.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 110  amos_0188.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 111  amos_0190.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 112  amos_0192.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 113  amos_0193.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 114  amos_0195.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 115  amos_0196.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 116  amos_0197.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 117  amos_0198.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 118  amos_0199.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 119  amos_0212.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 120  amos_0214.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 121  amos_0215.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 122  amos_0217.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 123  amos_0224.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 124  amos_0225.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 125  amos_0226.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 126  amos_0230.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 127  amos_0231.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 128  amos_0235.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 129  amos_0237.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 130  amos_0239.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 131  amos_0242.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 132  amos_0245.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 133  amos_0248.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 134  amos_0249.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 135  amos_0254.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 136  amos_0259.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 137  amos_0263.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 138  amos_0264.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 139  amos_0268.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 140  amos_0272.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 141  amos_0273.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 142  amos_0274.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 143  amos_0276.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 144  amos_0279.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 145  amos_0281.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 146  amos_0282.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 147  amos_0288.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 148  amos_0294.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 149  amos_0296.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 150  amos_0297.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 151  amos_0299.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 152  amos_0301.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 153  amos_0302.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 154  amos_0307.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 155  amos_0317.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 156  amos_0320.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 157  amos_0321.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 158  amos_0330.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 159  amos_0332.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 160  amos_0336.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 161  amos_0337.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 162  amos_0341.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 163  amos_0348.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 164  amos_0349.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 165  amos_0350.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 166  amos_0351.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 167  amos_0353.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 168  amos_0358.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 169  amos_0361.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 170  amos_0362.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 171  amos_0366.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 172  amos_0367.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 173  amos_0370.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 174  amos_0371.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 175  amos_0374.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 176  amos_0376.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 177  amos_0378.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 178  amos_0379.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 179  amos_0380.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 180  amos_0381.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 181  amos_0383.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 182  amos_0384.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 183  amos_0387.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 184  amos_0388.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 185  amos_0390.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 186  amos_0391.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 187  amos_0392.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 188  amos_0395.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 189  amos_0396.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 190  amos_0398.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 191  amos_0400.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 192  amos_0401.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 193  amos_0402.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 194  amos_0403.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 195  amos_0404.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 196  amos_0405.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 197  amos_0406.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 198  amos_0408.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
# 199  amos_0410.nii.gz  (192, 192, 192)  (1.0, 1.0, 1.0)
#
#                                                 Affine
# 0    [[1.0, 0.0, 0.0, 233.0], [0.0, 1.0, 0.0, -373....
# 1    [[1.0, 0.0, 0.0, 195.8979949951172], [0.0, 1.0...
# 2    [[1.0, 0.0, 0.0, 240.5], [0.0, 1.0, 0.0, -374....
# 3    [[1.0, 0.0, 0.0, 217.35569763183594], [0.0, 1....
# 4    [[1.0, 0.0, 0.0, 197.0], [0.0, 1.0, 0.0, -350....
# 5    [[1.0, 0.0, 0.0, 202.73390197753906], [0.0, 1....
# 6    [[1.0, 0.0, 0.0, 208.5800018310547], [0.0, 1.0...
# 7    [[1.0, 0.0, 0.0, 204.68710327148438], [0.0, 1....
# 8    [[1.0, 0.0, 0.0, 183.20269775390625], [0.0, 1....
# 9    [[1.0, 0.0, 0.0, 268.5], [0.0, 1.0, 0.0, -399....
# 10   [[1.0, 0.0, 0.0, 201.7574005126953], [0.0, 1.0...
# 11   [[1.0, 0.0, 0.0, 153.9058074951172], [0.0, 1.0...
# 12   [[1.0, 0.0, 0.0, 222.26519775390625], [0.0, 1....
# 13   [[1.0, 0.0, 0.0, 247.60049438476562], [0.0, 1....
# 14   [[1.0, 0.0, 0.0, 192.9683074951172], [0.0, 1.0...
# 15   [[1.0, 0.0, 0.0, 201.7574005126953], [0.0, 1.0...
# 16   [[1.0, 0.0, 0.0, 182.22610473632812], [0.0, 1....
# 17   [[1.0, 0.0, 0.0, 204.68710327148438], [0.0, 1....
# 18   [[1.0, 0.0, 0.0, 203.64759826660156], [0.0, 1....
# 19   [[1.0, 0.0, 0.0, 172.4604949951172], [0.0, 1.0...
# 20   [[1.0, 0.0, 0.0, 263.1911926269531], [0.0, 1.0...
# 21   [[1.0, 0.0, 0.0, 204.63369750976562], [0.0, 1....
# 22   [[1.0, 0.0, 0.0, 199.6092987060547], [0.0, 1.0...
# 23   [[1.0, 0.0, 0.0, 215.42930603027344], [0.0, 1....
# 24   [[1.0, 0.0, 0.0, 223.21119689941406], [0.0, 1....
# 25   [[1.0, 0.0, 0.0, 218.0], [0.0, 1.0, 0.0, -354....
# 26   [[1.0, 0.0, 0.0, 260.0], [0.0, 1.0, 0.0, -399....
# 27   [[1.0, 0.0, 0.0, 215.0], [0.0, 1.0, 0.0, -394....
# 28   [[1.0, 0.0, 0.0, 249.5], [0.0, 1.0, 0.0, -367....
# 29   [[1.0, 0.0, 0.0, 215.0], [0.0, 1.0, 0.0, -363....
# 30   [[1.0, 0.0, 0.0, 234.5], [0.0, 1.0, 0.0, -386....
# 31   [[1.0, 0.0, 0.0, 228.5], [0.0, 1.0, 0.0, -370....
# 32   [[1.0, 0.0, 0.0, 240.0], [0.0, 1.0, 0.0, -403....
# 33   [[1.0, 0.0, 0.0, 278.0], [0.0, 1.0, 0.0, -403....
# 34   [[1.0, 0.0, 0.0, 240.0], [0.0, 1.0, 0.0, -398....
# 35   [[1.0, 0.0, 0.0, 221.28860473632812], [0.0, 1....
# 36   [[1.0, 0.0, 0.0, 193.5], [0.0, 1.0, 0.0, -357....
# 37   [[1.0, 0.0, 0.0, 209.5699005126953], [0.0, 1.0...
# 38   [[1.0, 0.0, 0.0, 190.03860473632812], [0.0, 1....
# 39   [[1.0, 0.0, 0.0, 212.4633026123047], [0.0, 1.0...
# 40   [[1.0, 0.0, 0.0, 225.185302734375], [0.0, 1.0,...
# 41   [[1.0, 0.0, 0.0, 247.6291046142578], [0.0, 1.0...
# 42   [[1.0, 0.0, 0.0, 227.0], [0.0, 1.0, 0.0, -388....
# 43   [[1.0, 0.0, 0.0, 192.9683074951172], [0.0, 1.0...
# 44   [[1.0, 0.0, 0.0, 186.5], [0.0, 1.0, 0.0, -350....
# 45   [[1.0, 0.0, 0.0, 250.0], [0.0, 1.0, 0.0, -391....
# 46   [[1.0, 0.0, 0.0, 186.1324005126953], [0.0, 1.0...
# 47   [[1.0, 0.0, 0.0, 211.5], [0.0, 1.0, 0.0, -342....
# 48   [[1.0, 0.0, 0.0, 220.5], [0.0, 1.0, 0.0, -378....
# 49   [[1.0, 0.0, 0.0, 210.54640197753906], [0.0, 1....
# 50   [[1.0, 0.0, 0.0, 211.5229949951172], [0.0, 1.0...
# 51   [[1.0, 0.0, 0.0, 230.0395965576172], [0.0, 1.0...
# 52   [[1.0, 0.0, 0.0, 194.1573944091797], [0.0, 1.0...
# 53   [[1.0, 0.0, 0.0, 264.1754150390625], [0.0, 1.0...
# 54   [[1.0, 0.0, 0.0, 195.8979949951172], [0.0, 1.0...
# 55   [[1.0, 0.0, 0.0, 217.3614044189453], [0.0, 1.0...
# 56   [[1.0, 0.0, 0.0, 279.7392883300781], [0.0, 1.0...
# 57   [[1.0, 0.0, 0.0, 222.26519775390625], [0.0, 1....
# 58   [[1.0, 0.0, 0.0, 234.0], [0.0, 1.0, 0.0, -392....
# 59   [[1.0, 0.0, 0.0, 267.5], [0.0, 1.0, 0.0, -402....
# 60   [[1.0, 0.0, 0.0, 212.0], [0.0, 1.0, 0.0, -393....
# 61   [[1.0, 0.0, 0.0, 191.99180603027344], [0.0, 1....
# 62   [[1.0, 0.0, 0.0, 236.5], [0.0, 1.0, 0.0, -366....
# 63   [[1.0, 0.0, 0.0, 229.0], [0.0, 1.0, 0.0, -406....
# 64   [[1.0, 0.0, 0.0, 202.73390197753906], [0.0, 1....
# 65   [[1.0, 0.0, 0.0, 230.07769775390625], [0.0, 1....
# 66   [[1.0, 0.0, 0.0, 254.5], [0.0, 1.0, 0.0, -405....
# 67   [[1.0, 0.0, 0.0, 210.5], [0.0, 1.0, 0.0, -341....
# 68   [[1.0, 0.0, 0.0, 226.10850524902344], [0.0, 1....
# 69   [[1.0, 0.0, 0.0, 281.7992858886719], [0.0, 1.0...
# 70   [[1.0, 0.0, 0.0, 222.26519775390625], [0.0, 1....
# 71   [[1.0, 0.0, 0.0, 238.78469848632812], [0.0, 1....
# 72   [[1.0, 0.0, 0.0, 217.29849243164062], [0.0, 1....
# 73   [[1.0, 0.0, 0.0, 226.0], [0.0, 1.0, 0.0, -371....
# 74   [[1.0, 0.0, 0.0, 178.5614013671875], [0.0, 1.0...
# 75   [[1.0, 0.0, 0.0, 189.06210327148438], [0.0, 1....
# 76   [[1.0, 0.0, 0.0, 202.73390197753906], [0.0, 1....
# 77   [[1.0, 0.0, 0.0, 257.0], [0.0, 1.0, 0.0, -410....
# 78   [[1.0, 0.0, 0.0, 195.0], [0.0, 1.0, 0.0, -341....
# 79   [[1.0, 0.0, 0.0, 212.4633026123047], [0.0, 1.0...
# 80   [[1.0, 0.0, 0.0, 264.1543884277344], [0.0, 1.0...
# 81   [[1.0, 0.0, 0.0, 280.7388000488281], [0.0, 1.0...
# 82   [[1.0, 0.0, 0.0, 199.6092987060547], [0.0, 1.0...
# 83   [[1.0, 0.0, 0.0, 264.19830322265625], [0.0, 1....
# 84   [[1.0, 0.0, 0.0, 238.5], [0.0, 1.0, 0.0, -398....
# 85   [[1.0, 0.0, 0.0, 218.5], [0.0, 1.0, 0.0, -371....
# 86   [[1.0, 0.0, 0.0, 195.89990234375], [0.0, 1.0, ...
# 87   [[1.0, 0.0, 0.0, 236.85260009765625], [0.0, 1....
# 88   [[1.0, 0.0, 0.0, 199.80430603027344], [0.0, 1....
# 89   [[1.0, 0.0, 0.0, 221.27529907226562], [0.0, 1....
# 90   [[1.0, 0.0, 0.0, 208.5933074951172], [0.0, 1.0...
# 91   [[1.0, 0.0, 0.0, 194.1573944091797], [0.0, 1.0...
# 92   [[1.0, 0.0, 0.0, 199.6092987060547], [0.0, 1.0...
# 93   [[1.0, 0.0, 0.0, 222.2404022216797], [0.0, 1.0...
# 94   [[1.0, 0.0, 0.0, 229.0572967529297], [0.0, 1.0...
# 95   [[1.0, 0.0, 0.0, 215.39109802246094], [0.0, 1....
# 96   [[1.0, 0.0, 0.0, 196.87460327148438], [0.0, 1....
# 97   [[1.0, 0.0, 0.0, 180.2729949951172], [0.0, 1.0...
# 98   [[1.0, 0.0, 0.0, 244.6746063232422], [0.0, 1.0...
# 99   [[1.0, 0.0, 0.0, 259.0], [0.0, 1.0, 0.0, -373....
# 100  [[1.0, 0.0, 0.0, 220.0], [0.0, 1.0, 0.0, -403....
# 101  [[1.0, 0.0, 0.0, 268.5], [0.0, 1.0, 0.0, -386....
# 102  [[1.0, 0.0, 0.0, 205.66360473632812], [0.0, 1....
# 103  [[1.0, 0.0, 0.0, 201.7574005126953], [0.0, 1.0...
# 104  [[1.0, 0.0, 0.0, 205.66360473632812], [0.0, 1....
# 105  [[1.0, 0.0, 0.0, 222.5], [0.0, 1.0, 0.0, -370....
# 106  [[1.0, 0.0, 0.0, 225.15289306640625], [0.0, 1....
# 107  [[1.0, 0.0, 0.0, 217.3594970703125], [0.0, 1.0...
# 108  [[1.0, 0.0, 0.0, 237.8157958984375], [0.0, 1.0...
# 109  [[1.0, 0.0, 0.0, 168.0], [0.0, 1.0, 0.0, -363....
# 110  [[1.0, 0.0, 0.0, 203.7104949951172], [0.0, 1.0...
# 111  [[1.0, 0.0, 0.0, 195.89230346679688], [0.0, 1....
# 112  [[1.0, 0.0, 0.0, 221.28860473632812], [0.0, 1....
# 113  [[1.0, 0.0, 0.0, 205.6121063232422], [0.0, 1.0...
# 114  [[1.0, 0.0, 0.0, 269.0544128417969], [0.0, 1.0...
# 115  [[1.0, 0.0, 0.0, 218.35890197753906], [0.0, 1....
# 116  [[1.0, 0.0, 0.0, 177.3986053466797], [0.0, 1.0...
# 117  [[1.0, 0.0, 0.0, 217.33279418945312], [0.0, 1....
# 118  [[1.0, 0.0, 0.0, 223.0], [0.0, 1.0, 0.0, -335....
# 119  [[1.0, 0.0, 0.0, 154.2275390625], [0.0, 1.0, 0...
# 120  [[1.0, 0.0, 0.0, 224.57421875], [0.0, 1.0, 0.0...
# 121  [[1.0, 0.0, 0.0, 170.654296875], [0.0, 1.0, 0....
# 122  [[1.0, 0.0, 0.0, 166.65625], [0.0, 1.0, 0.0, -...
# 123  [[1.0, 0.0, 0.0, 166.1630859375], [0.0, 1.0, 0...
# 124  [[1.0, 0.0, 0.0, 157.2177734375], [0.0, 1.0, 0...
# 125  [[1.0, 0.0, 0.0, 150.69140625], [0.0, 1.0, 0.0...
# 126  [[1.0, 0.0, 0.0, 166.671875], [0.0, 1.0, 0.0, ...
# 127  [[1.0, 0.0, 0.0, 197.6999969482422], [0.0, 1.0...
# 128  [[1.0, 0.0, 0.0, 183.65625], [0.0, 1.0, 0.0, -...
# 129  [[1.0, 0.0, 0.0, 158.671875], [0.0, 1.0, 0.0, ...
# 130  [[1.0, 0.0, 0.0, 170.666015625], [0.0, 1.0, 0....
# 131  [[1.0, 0.0, 0.0, 152.1767578125], [0.0, 1.0, 0...
# 132  [[1.0, 0.0, 0.0, 192.39999389648438], [0.0, 1....
# 133  [[1.0, 0.0, 0.0, 172.1552734375], [0.0, 1.0, 0...
# 134  [[1.0, 0.0, 0.0, 162.68359375], [0.0, 1.0, 0.0...
# 135  [[1.0, 0.0, 0.0, 144.701171875], [0.0, 1.0, 0....
# 136  [[1.0, 0.0, 0.0, 161.60000610351562], [0.0, 1....
# 137  [[1.0, 0.0, 0.0, 160.662109375], [0.0, 1.0, 0....
# 138  [[1.0, 0.0, 0.0, 188.1357421875], [0.0, 1.0, 0...
# 139  [[1.0, 0.0, 0.0, 158.67578125], [0.0, 1.0, 0.0...
# 140  [[1.0, 0.0, 0.0, 178.685546875], [0.0, 1.0, 0....
# 141  [[1.0, 0.0, 0.0, 171.625], [0.0, 1.0, 0.0, -23...
# 142  [[1.0, 0.0, 0.0, 171.65625], [0.0, 1.0, 0.0, -...
# 143  [[1.0, 0.0, 0.0, 158.1943359375], [0.0, 1.0, 0...
# 144  [[1.0, 0.0, 0.0, 174.8000030517578], [0.0, 1.0...
# 145  [[1.0, 0.0, 0.0, 143.71484375], [0.0, 1.0, 0.0...
# 146  [[1.0, 0.0, 0.0, 204.1064453125], [0.0, 1.0, 0...
# 147  [[1.0, 0.0, 0.0, 198.6999969482422], [0.0, 1.0...
# 148  [[1.0, 0.0, 0.0, 172.1611328125], [0.0, 1.0, 0...
# 149  [[1.0, 0.0, 0.0, 213.8000030517578], [0.0, 1.0...
# 150  [[1.0, 0.0, 0.0, 200.615234375], [0.0, 1.0, 0....
# 151  [[1.0, 0.0, 0.0, 187.0], [0.0, 1.0, 0.0, -198....
# 152  [[1.0, 0.0, 0.0, 174.1999969482422], [0.0, 1.0...
# 153  [[1.0, 0.0, 0.0, 154.69140625], [0.0, 1.0, 0.0...
# 154  [[1.0, 0.0, 0.0, 152.6640625], [0.0, 1.0, 0.0,...
# 155  [[1.0, 0.0, 0.0, 164.1923828125], [0.0, 1.0, 0...
# 156  [[1.0, 0.0, 0.0, 168.6875], [0.0, 1.0, 0.0, -1...
# 157  [[1.0, 0.0, 0.0, 180.640625], [0.0, 1.0, 0.0, ...
# 158  [[1.0, 0.0, 0.0, 154.689453125], [0.0, 1.0, 0....
# 159  [[1.0, 0.0, 0.0, 161.658203125], [0.0, 1.0, 0....
# 160  [[1.0, 0.0, 0.0, 210.603515625], [0.0, 1.0, 0....
# 161  [[1.0, 0.0, 0.0, 183.1259765625], [0.0, 1.0, 0...
# 162  [[1.0, 0.0, 0.0, 152.6953125], [0.0, 1.0, 0.0,...
# 163  [[1.0, 0.0, 0.0, 166.662109375], [0.0, 1.0, 0....
# 164  [[1.0, 0.0, 0.0, 176.6484375], [0.0, 1.0, 0.0,...
# 165  [[1.0, 0.0, 0.0, 151.689453125], [0.0, 1.0, 0....
# 166  [[1.0, 0.0, 0.0, 168.89999389648438], [0.0, 1....
# 167  [[1.0, 0.0, 0.0, 177.1748046875], [0.0, 1.0, 0...
# 168  [[1.0, 0.0, 0.0, 157.8000030517578], [0.0, 1.0...
# 169  [[1.0, 0.0, 0.0, 219.5], [0.0, 1.0, 0.0, -357....
# 170  [[1.0, 0.0, 0.0, 240.5], [0.0, 1.0, 0.0, -384....
# 171  [[1.0, 0.0, 0.0, 195.5], [0.0, 1.0, 0.0, -354....
# 172  [[1.0, 0.0, 0.0, 265.0], [0.0, 1.0, 0.0, -408....
# 173  [[1.0, 0.0, 0.0, 265.0], [0.0, 1.0, 0.0, -411....
# 174  [[1.0, 0.0, 0.0, 207.0], [0.0, 1.0, 0.0, -364....
# 175  [[1.0, 0.0, 0.0, 271.0], [0.0, 1.0, 0.0, -415....
# 176  [[1.0, 0.0, 0.0, 226.5], [0.0, 1.0, 0.0, -363....
# 177  [[1.0, 0.0, 0.0, 229.0], [0.0, 1.0, 0.0, -378....
# 178  [[1.0, 0.0, 0.0, 236.5], [0.0, 1.0, 0.0, -409....
# 179  [[1.0, 0.0, 0.0, 227.0], [0.0, 1.0, 0.0, -381....
# 180  [[1.0, 0.0, 0.0, 256.0], [0.0, 1.0, 0.0, -417....
# 181  [[1.0, 0.0, 0.0, 240.5], [0.0, 1.0, 0.0, -392....
# 182  [[1.0, 0.0, 0.0, 190.5], [0.0, 1.0, 0.0, -316....
# 183  [[1.0, 0.0, 0.0, 222.5], [0.0, 1.0, 0.0, -368....
# 184  [[1.0, 0.0, 0.0, 215.0], [0.0, 1.0, 0.0, -354....
# 185  [[1.0, 0.0, 0.0, 225.5], [0.0, 1.0, 0.0, -386....
# 186  [[1.0, 0.0, 0.0, 256.0], [0.0, 1.0, 0.0, -409....
# 187  [[1.0, 0.0, 0.0, 203.0], [0.0, 1.0, 0.0, -364....
# 188  [[1.0, 0.0, 0.0, 183.5], [0.0, 1.0, 0.0, -347....
# 189  [[1.0, 0.0, 0.0, 218.0], [0.0, 1.0, 0.0, -415....
# 190  [[1.0, 0.0, 0.0, 241.0], [0.0, 1.0, 0.0, -374....
# 191  [[1.0, 0.0, 0.0, 202.5], [0.0, 1.0, 0.0, -348....
# 192  [[1.0, 0.0, 0.0, 205.5], [0.0, 1.0, 0.0, -370....
# 193  [[1.0, 0.0, 0.0, 226.0], [0.0, 1.0, 0.0, -369....
# 194  [[1.0, 0.0, 0.0, 228.0], [0.0, 1.0, 0.0, -380....
# 195  [[1.0, 0.0, 0.0, 199.5], [0.0, 1.0, 0.0, -373....
# 196  [[1.0, 0.0, 0.0, 209.0], [0.0, 1.0, 0.0, -395....
# 197  [[1.0, 0.0, 0.0, 216.5], [0.0, 1.0, 0.0, -381....
# 198  [[1.0, 0.0, 0.0, 216.0], [0.0, 1.0, 0.0, -410....
# 199  [[1.0, 0.0, 0.0, 258.0], [0.0, 1.0, 0.0, -373....

# %%
# Cell 1: Install SimpleITK if needed
# !pip install SimpleITK

# Cell 2: Import libraries
import os
import SimpleITK as sitk

# Cell 3: Define paths
input_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTr/"    # Replace with your AMOS images folder
output_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/"   # Replace with your desired output folder
os.makedirs(output_dir, exist_ok=True)

# Cell 4: Define target spacing
# Here we pick (1.0, 1.0, 3.0) as an example; adjust as needed.
target_spacing = (1.0, 1.0, 3.0)  # (X, Y, Z) in mm

# Cell 5: Resampling function
def resample_image(image, target_spacing, is_label=False):
    original_spacing = image.GetSpacing()
    original_size = image.GetSize()
    
    # Calculate new size
    new_size = [
        int(round(original_size[i] * (original_spacing[i] / target_spacing[i])))
        for i in range(3)
    ]
    
    resampler = sitk.ResampleImageFilter()
    resampler.SetOutputSpacing(target_spacing)
    resampler.SetSize(new_size)
    resampler.SetOutputDirection(image.GetDirection())
    resampler.SetOutputOrigin(image.GetOrigin())
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    
    resampled_image = resampler.Execute(image)
    return resampled_image

# Cell 6: Process all images
nifti_files = [f for f in os.listdir(input_dir) if f.endswith('.nii') or f.endswith('.nii.gz')]

for file in sorted(nifti_files):
    file_path = os.path.join(input_dir, file)
    image = sitk.ReadImage(file_path)
    resampled = resample_image(image, target_spacing)
    
    output_path = os.path.join(output_dir, file)
    sitk.WriteImage(resampled, output_path)
    
    print(f"Resampled: {file} -> Shape: {resampled.GetSize()}, Spacing: {resampled.GetSpacing()}")

print("✅ Resampling complete!")
# Out:
# Resampled: amos_0507.nii.gz -> Shape: (380, 344, 60), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0508.nii.gz -> Shape: (366, 120, 150), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0510.nii.gz -> Shape: (366, 156, 150), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0514.nii.gz -> Shape: (366, 168, 150), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0517.nii.gz -> Shape: (400, 400, 77), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0518.nii.gz -> Shape: (400, 240, 133), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0522.nii.gz -> Shape: (440, 358, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0530.nii.gz -> Shape: (380, 344, 64), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0532.nii.gz -> Shape: (420, 341, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0538.nii.gz -> Shape: (420, 341, 64), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0540.nii.gz -> Shape: (375, 375, 67), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0541.nii.gz -> Shape: (380, 344, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0548.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0551.nii.gz -> Shape: (400, 325, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0554.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0555.nii.gz -> Shape: (400, 322, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0557.nii.gz -> Shape: (420, 167, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0558.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0570.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0571.nii.gz -> Shape: (400, 322, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0578.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0580.nii.gz -> Shape: (380, 180, 127), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0582.nii.gz -> Shape: (380, 180, 127), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0583.nii.gz -> Shape: (380, 180, 127), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0584.nii.gz -> Shape: (400, 322, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0585.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0586.nii.gz -> Shape: (366, 216, 150), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0587.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0588.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0589.nii.gz -> Shape: (380, 180, 127), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0590.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0591.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0592.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0593.nii.gz -> Shape: (400, 325, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0594.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0595.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0596.nii.gz -> Shape: (420, 185, 140), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0597.nii.gz -> Shape: (380, 180, 127), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0599.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# Resampled: amos_0600.nii.gz -> Shape: (380, 309, 72), Spacing: (1.0, 1.0, 3.0)
# ✅ Resampling complete!

# %%
# -*- coding: utf-8 -*-
"""
NIfTI Resampling & Resizing Utility
-----------------------------------
• Reads every *.nii* / *.nii.gz* file in *input_dir*.
• Resamples to **1 × 1 × 1 mm** voxel spacing (linear interpolation).
• Resizes to **192 × 192 × 192** voxels (keeps origin & direction).
• Saves the processed image with the **same file‑name** inside *output_dir*.
• Prints old/new shape & spacing for quick verification.

Requirements
============
```
pip install SimpleITK
```

Edit `INPUT_DIR` / `OUTPUT_DIR` if you move the folders.
"""

from __future__ import annotations
import os
from pathlib import Path
from typing import Tuple, List
import SimpleITK as sitk
import matplotlib.pyplot as plt

# ────────────────────────────────────────────────────────────────────────────────
# CONFIGURATION (update if your folders change)
# ────────────────────────────────────────────────────────────────────────────────
INPUT_DIR  = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTr")
OUTPUT_DIR = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

TARGET_SPACING: Tuple[float, float, float] = (1.0, 1.0, 1.0)  # mm (x, y, z)
TARGET_SHAPE:   Tuple[int,  int,  int]   = (192, 192, 192)   # voxels (x, y, z)

# ────────────────────────────────────────────────────────────────────────────────
# HELPER FUNCTIONS
# ────────────────────────────────────────────────────────────────────────────────

def resample_to_spacing(img: sitk.Image, spacing: Tuple[float, float, float], is_label: bool = False) -> sitk.Image:
    """Resample *img* to *spacing*.
    Linear for images, NearestNeighbour for labels.
    """
    orig_spacing = img.GetSpacing()
    orig_size    = img.GetSize()
    new_size     = [int(round(osz * (osp / nsp))) for osz, osp, nsp in zip(orig_size, orig_spacing, spacing)]

    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(spacing)
    resampler.SetSize(new_size)
    resampler.SetOutputDirection(img.GetDirection())
    resampler.SetOutputOrigin(img.GetOrigin())
    return resampler.Execute(img)


def resize_to_shape(img: sitk.Image, shape: Tuple[int, int, int], is_label: bool = False) -> sitk.Image:
    """Resize *img* to *shape* (changes spacing accordingly)."""
    curr_size    = img.GetSize()
    curr_spacing = img.GetSpacing()
    # new spacing so physical size stays similar after resizing
    new_spacing  = [csp * (csz / nsz) for csp, csz, nsz in zip(curr_spacing, curr_size, shape)]

    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(new_spacing)
    resampler.SetSize(shape)
    resampler.SetOutputDirection(img.GetDirection())
    resampler.SetOutputOrigin(img.GetOrigin())
    return resampler.Execute(img)


# ────────────────────────────────────────────────────────────────────────────────
# PROCESS LOOP
# ────────────────────────────────────────────────────────────────────────────────
nii_files: List[Path] = sorted(INPUT_DIR.glob("*.nii*"))
if not nii_files:
    raise FileNotFoundError(f"No NIfTI files found in {INPUT_DIR}")

for idx, file_path in enumerate(nii_files, 1):
    img = sitk.ReadImage(str(file_path))
    orig_shape   = img.GetSize()
    orig_spacing = img.GetSpacing()

    # Step‑1  Resample to isotropic spacing -------------------------------------
    img_iso = resample_to_spacing(img, TARGET_SPACING)

    # Step‑2  Resize to target shape --------------------------------------------
    img_iso_resized = resize_to_shape(img_iso, TARGET_SHAPE)

    # Save & report -------------------------------------------------------------
    out_path = OUTPUT_DIR / file_path.name
    sitk.WriteImage(img_iso_resized, str(out_path))

    print(
        f"[{idx:03d}/{len(nii_files):03d}] {file_path.name}\n"
        f"  ‣ original shape  {orig_shape}  spacing {orig_spacing}\n"
        f"  ‣ new      shape  {img_iso_resized.GetSize()}  spacing {img_iso_resized.GetSpacing()}\n"
    )

print("\n✅ All volumes resampled & resized to 1 mm and 192³")
# Out:
# [001/040] amos_0507.nii.gz
#   ‣ original shape  (320, 290, 72)  spacing (1.1875, 1.1875, 2.5)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.7916666666666667, 0.9375)
#
# [002/040] amos_0508.nii.gz
#   ‣ original shape  (260, 80, 320)  spacing (1.40625, 1.5, 1.40625)
#   ‣ new      shape  (192, 192, 192)  spacing (1.90625, 0.625, 2.34375)
#
# [003/040] amos_0510.nii.gz
#   ‣ original shape  (260, 104, 320)  spacing (1.40625, 1.5, 1.40625)
#   ‣ new      shape  (192, 192, 192)  spacing (1.90625, 0.8125, 2.34375)
#
# [004/040] amos_0514.nii.gz
#   ‣ original shape  (260, 112, 320)  spacing (1.40625, 1.5, 1.40625)
#   ‣ new      shape  (192, 192, 192)  spacing (1.90625, 0.875, 2.34375)
#
# [005/040] amos_0517.nii.gz
#   ‣ original shape  (400, 400, 115)  spacing (1.0, 1.0, 2.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 2.0833333333333335, 1.1979166666666667)
#
# [006/040] amos_0518.nii.gz
#   ‣ original shape  (400, 120, 400)  spacing (1.0, 2.0, 1.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.25, 2.0833333333333335)
#
# [007/040] amos_0522.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.375, 1.375, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.2916666666666665, 1.8645833333333333, 1.125)
#
# [008/040] amos_0530.nii.gz
#   ‣ original shape  (320, 290, 64)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.7916666666666667, 1.0)
#
# [009/040] amos_0532.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.3125, 1.3125, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 1.7760416666666667, 1.125)
#
# [010/040] amos_0538.nii.gz
#   ‣ original shape  (320, 260, 64)  spacing (1.3125, 1.3125, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 1.7760416666666667, 1.0)
#
# [011/040] amos_0540.nii.gz
#   ‣ original shape  (192, 192, 100)  spacing (1.953125, 1.953125, 2.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.953125, 1.953125, 1.0416666666666667)
#
# [012/040] amos_0541.nii.gz
#   ‣ original shape  (320, 290, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.7916666666666667, 1.125)
#
# [013/040] amos_0548.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [014/040] amos_0551.nii.gz
#   ‣ original shape  (576, 468, 72)  spacing (0.6944444179534912, 0.6944444179534912, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.6927083333333333, 1.125)
#
# [015/040] amos_0554.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [016/040] amos_0555.nii.gz
#   ‣ original shape  (288, 232, 72)  spacing (1.3888888359069824, 1.3888888359069824, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.6770833333333333, 1.125)
#
# [017/040] amos_0557.nii.gz
#   ‣ original shape  (512, 152, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.8697916666666666, 2.1875)
#
# [018/040] amos_0558.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [019/040] amos_0570.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [020/040] amos_0571.nii.gz
#   ‣ original shape  (320, 258, 72)  spacing (1.25, 1.25, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.6770833333333333, 1.125)
#
# [021/040] amos_0578.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [022/040] amos_0580.nii.gz
#   ‣ original shape  (320, 60, 320)  spacing (1.1875, 3.0, 1.1875)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 0.9375, 1.9791666666666667)
#
# [023/040] amos_0582.nii.gz
#   ‣ original shape  (320, 60, 320)  spacing (1.1875, 3.0, 1.1875)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 0.9375, 1.9791666666666667)
#
# [024/040] amos_0583.nii.gz
#   ‣ original shape  (320, 60, 320)  spacing (1.1875, 3.0, 1.1875)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 0.9375, 1.9791666666666667)
#
# [025/040] amos_0584.nii.gz
#   ‣ original shape  (288, 232, 72)  spacing (1.3888888359069824, 1.3888888359069824, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.6770833333333333, 1.125)
#
# [026/040] amos_0585.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [027/040] amos_0586.nii.gz
#   ‣ original shape  (260, 144, 320)  spacing (1.4062999486923218, 1.5, 1.4062999486923218)
#   ‣ new      shape  (192, 192, 192)  spacing (1.90625, 1.125, 2.34375)
#
# [028/040] amos_0587.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [029/040] amos_0588.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [030/040] amos_0589.nii.gz
#   ‣ original shape  (320, 60, 320)  spacing (1.1875, 3.0, 1.1875)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 0.9375, 1.9791666666666667)
#
# [031/040] amos_0590.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [032/040] amos_0591.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [033/040] amos_0592.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [034/040] amos_0593.nii.gz
#   ‣ original shape  (576, 468, 72)  spacing (0.6944444179534912, 0.6944444179534912, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (2.0833333333333335, 1.6927083333333333, 1.125)
#
# [035/040] amos_0594.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [036/040] amos_0595.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [037/040] amos_0596.nii.gz
#   ‣ original shape  (512, 168, 512)  spacing (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   ‣ new      shape  (192, 192, 192)  spacing (2.1875, 0.9635416666666666, 2.1875)
#
# [038/040] amos_0597.nii.gz
#   ‣ original shape  (320, 60, 320)  spacing (1.1875, 3.0, 1.1875)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 0.9375, 1.9791666666666667)
#
# [039/040] amos_0599.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
# [040/040] amos_0600.nii.gz
#   ‣ original shape  (320, 260, 72)  spacing (1.1875, 1.1875, 3.0)
#   ‣ new      shape  (192, 192, 192)  spacing (1.9791666666666667, 1.609375, 1.125)
#
#
# ✅ All volumes resampled & resized to 1 mm and 192³

# %%
# Resample and reshape AMOS22 MRI dataset to 1x1x1 mm voxel size and target shape

# Import required libraries
import numpy as np
import os
import nibabel as nib
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

# Define paths
input_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTr/"
output_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define target voxel spacing and shape
target_spacing = [1.0, 1.0, 1.0]  # mm
target_shape = [192, 192, 192]

# Loop over all NIfTI files in the input directory
for filename in sorted(os.listdir(input_dir)):
    if filename.endswith(".nii") or filename.endswith(".nii.gz"):
        print(f"Processing: {filename}")
        
        # Load the NIfTI file
        img_path = os.path.join(input_dir, filename)
        img_nii = nib.load(img_path)
        img_data = img_nii.get_fdata()
        img_affine = img_nii.affine
        
        # Print some info
        print(f"  Original shape: {img_data.shape}")
        print(f"  Affine:\n{img_affine}")
        
        # Extract voxel dimensions from the affine matrix
        voxel_spacing = np.abs(img_affine[:3, :3]).sum(axis=0)
        print(f"  Original voxel spacing: {voxel_spacing}")

        # Compute the rescaling factors
        scale_factors = voxel_spacing / target_spacing
        print(f"  Scale factors: {scale_factors}")
        
        # Resample to isotropic spacing
        img_resampled = zoom(img_data, scale_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Resampled shape: {img_resampled.shape}")
        
        # Compute resizing factors to target shape
        resize_factors = (
            target_shape[0] / img_resampled.shape[0],
            target_shape[1] / img_resampled.shape[1],
            target_shape[2] / img_resampled.shape[2]
        )
        print(f"  Resize factors: {resize_factors}")
        
        # Resize to target shape
        img_resized = zoom(img_resampled, resize_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Final shape: {img_resized.shape}")
        
        # Save the processed image
        # Adjust the affine to reflect the new voxel spacing
        new_affine = np.copy(img_affine)
        new_affine[:3, :3] = np.diag(target_spacing)
        
        out_img = nib.Nifti1Image(img_resized.astype(np.float32), new_affine)
        out_path = os.path.join(output_dir, filename)
        nib.save(out_img, out_path)
        print(f"  Saved to: {out_path}\n")

print("Processing complete!")
# Out:
# Processing: amos_0507.nii.gz
#   Original shape: (320, 290, 72)
#   Affine:
# [[   1.1875        0.            0.         -183.16921997]
#  [   0.            1.1875        0.         -172.01393127]
#  [   0.            0.            2.5         -60.35303497]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 2.5   ]
#   Scale factors: [1.1875 1.1875 2.5   ]
#   Resampled shape: (380, 344, 180)
#   Resize factors: (0.5052631578947369, 0.5581395348837209, 1.0666666666666667)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0507.nii.gz
#
# Processing: amos_0508.nii.gz
#   Original shape: (260, 80, 320)
#   Affine:
# [[ 1.40607679e+00  1.51430687e-03  2.20219977e-02 -2.10871536e+02]
#  [-3.88847082e-04  1.49835980e+00 -6.57284036e-02 -6.30484047e+01]
#  [-2.20642835e-02  7.00951442e-02  1.40454042e+00 -2.33261093e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.42852992 1.56996925 1.49229082]
#   Scale factors: [1.42852992 1.56996925 1.49229082]
#   Resampled shape: (371, 126, 478)
#   Resize factors: (0.5175202156334232, 1.5238095238095237, 0.401673640167364)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0508.nii.gz
#
# Processing: amos_0510.nii.gz
#   Original shape: (260, 104, 320)
#   Affine:
# [[ 1.40558052e+00  4.18732092e-02 -1.84738319e-02 -2.14721313e+02]
#  [-3.98433693e-02  1.49859178e+00 -4.60590310e-02 -6.66952820e+01]
#  [ 1.71707384e-02  4.96645272e-02  1.40537405e+00 -2.28577194e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.46259463 1.59012952 1.46990691]
#   Scale factors: [1.46259463 1.59012952 1.46990691]
#   Resampled shape: (380, 165, 470)
#   Resize factors: (0.5052631578947369, 1.1636363636363636, 0.4085106382978723)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0510.nii.gz
#
# Processing: amos_0514.nii.gz
#   Original shape: (260, 112, 320)
#   Affine:
# [[ 1.40616596e+00  1.63927209e-02  1.33924361e-04 -1.66953217e+02]
#  [-1.53687429e-02  1.49985516e+00  1.22534391e-02 -9.29706879e+01]
#  [ 5.31112515e-11 -1.30711300e-02  1.40619659e+00 -2.02193237e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.4215347  1.52931901 1.41858396]
#   Scale factors: [1.4215347  1.52931901 1.41858396]
#   Resampled shape: (370, 171, 454)
#   Resize factors: (0.518918918918919, 1.1228070175438596, 0.42290748898678415)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0514.nii.gz
#
# Processing: amos_0517.nii.gz
#   Original shape: (400, 400, 115)
#   Affine:
# [[ 9.99995053e-01  1.35147083e-03  5.67058241e-03 -2.08009613e+02]
#  [-1.37441454e-03  9.99966204e-01  1.62120350e-02 -2.26957001e+02]
#  [-2.82422244e-03 -8.10982287e-03  1.99993885e+00 -1.83264786e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.00419369 1.0094275  2.02182146]
#   Scale factors: [1.00419369 1.0094275  2.02182146]
#   Resampled shape: (402, 404, 233)
#   Resize factors: (0.47761194029850745, 0.4752475247524752, 0.8240343347639485)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0517.nii.gz
#
# Processing: amos_0518.nii.gz
#   Original shape: (400, 120, 400)
#   Affine:
# [[ 9.99976575e-01 -1.33172767e-02  1.59582205e-03 -2.07148300e+02]
#  [ 6.64696703e-03  1.99989319e+00  7.23143155e-03 -1.47045456e+02]
#  [-1.64389680e-03 -1.44412350e-02  9.99972582e-01 -1.83113876e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.00826744 2.0276517  1.00879984]
#   Scale factors: [1.00826744 2.0276517  1.00879984]
#   Resampled shape: (403, 243, 404)
#   Resize factors: (0.47642679900744417, 0.7901234567901234, 0.4752475247524752)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0518.nii.gz
#
# Processing: amos_0522.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.375         0.            0.         -206.06602478]
#  [   0.            1.375         0.         -177.375     ]
#  [   0.            0.            3.          -50.33195496]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.375 1.375 3.   ]
#   Scale factors: [1.375 1.375 3.   ]
#   Resampled shape: (440, 358, 216)
#   Resize factors: (0.43636363636363634, 0.5363128491620112, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0522.nii.gz
#
# Processing: amos_0530.nii.gz
#   Original shape: (320, 290, 64)
#   Affine:
# [[ 1.18664038e+00 -7.24488345e-08 -1.14126973e-01 -1.86735687e+02]
#  [-7.67857819e-06  1.18750000e+00 -5.14360203e-04 -1.69153366e+02]
#  [ 4.51753065e-02  2.03745862e-04  2.99782515e+00 -1.07591583e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.23182337 1.18770382 3.11246648]
#   Scale factors: [1.23182337 1.18770382 3.11246648]
#   Resampled shape: (394, 344, 199)
#   Resize factors: (0.4873096446700508, 0.5581395348837209, 0.964824120603015)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0530.nii.gz
#
# Processing: amos_0532.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[ 1.31237221e+00  8.04717857e-08  4.18634713e-02 -1.91605774e+02]
#  [-5.83324891e-07  1.31250000e+00  8.23568189e-05 -1.67417831e+02]
#  [-1.83152799e-02 -3.60357590e-05  2.99970627e+00 -1.48325470e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.33068807 1.31253612 3.0416521 ]
#   Scale factors: [1.33068807 1.31253612 3.0416521 ]
#   Resampled shape: (426, 341, 219)
#   Resize factors: (0.4507042253521127, 0.5630498533724341, 0.8767123287671232)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0532.nii.gz
#
# Processing: amos_0538.nii.gz
#   Original shape: (320, 260, 64)
#   Affine:
# [[ 1.31104469e+00 -7.62163239e-08  1.41237706e-01 -1.89866516e+02]
#  [-5.38524682e-06  1.31250000e+00  2.64866278e-04 -1.68294479e+02]
#  [-6.17914833e-02 -1.16004005e-04  2.99667430e+00 -1.29532211e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.37284156 1.31261608 3.13817687]
#   Scale factors: [1.37284156 1.31261608 3.13817687]
#   Resampled shape: (439, 341, 201)
#   Resize factors: (0.43735763097949887, 0.5630498533724341, 0.9552238805970149)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0538.nii.gz
#
# Processing: amos_0540.nii.gz
#   Original shape: (192, 192, 100)
#   Affine:
# [[ 1.95157444e+00  2.58715055e-03 -7.96346143e-02 -1.66897858e+02]
#  [-2.58509885e-03  1.95312321e+00  1.05485808e-04 -1.87211975e+02]
#  [ 7.77682811e-02 -3.16819487e-11  1.99841309e+00 -8.47990341e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [2.03192782 1.95571036 2.07815319]
#   Scale factors: [2.03192782 1.95571036 2.07815319]
#   Resampled shape: (390, 375, 208)
#   Resize factors: (0.49230769230769234, 0.512, 0.9230769230769231)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0540.nii.gz
#
# Processing: amos_0541.nii.gz
#   Original shape: (320, 290, 72)
#   Affine:
# [[ 1.18740630e+00  3.09346326e-08  3.76759171e-02 -1.85255432e+02]
#  [ 5.23596782e-06  1.18749988e+00 -1.05941016e-03 -1.75382019e+02]
#  [-1.49134193e-02  4.19383578e-04  2.99975586e+00 -1.61514950e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.20232496 1.1879193  3.03849119]
#   Scale factors: [1.20232496 1.1879193  3.03849119]
#   Resampled shape: (385, 344, 219)
#   Resize factors: (0.4987012987012987, 0.5581395348837209, 0.8767123287671232)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0541.nii.gz
#
# Processing: amos_0548.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -189.09428406]
#  [   0.            1.1875        0.         -150.55632019]
#  [   0.            0.            3.         -159.06413269]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0548.nii.gz
#
# Processing: amos_0551.nii.gz
#   Original shape: (576, 468, 72)
#   Affine:
# [[   0.69444442    0.            0.         -233.18486023]
#  [   0.            0.69444442    0.         -161.92381287]
#  [   0.            0.            3.         -158.69277954]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.69444442 0.69444442 3.        ]
#   Scale factors: [0.69444442 0.69444442 3.        ]
#   Resampled shape: (400, 325, 216)
#   Resize factors: (0.48, 0.5907692307692308, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0551.nii.gz
#
# Processing: amos_0554.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -198.85327148]
#  [   0.            1.1000061     0.          -76.05190277]
#  [   0.            0.            0.82029998 -209.58328247]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.1000061  0.82029998]
#   Scale factors: [0.82029998 1.1000061  0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0554.nii.gz
#
# Processing: amos_0555.nii.gz
#   Original shape: (288, 232, 72)
#   Affine:
# [[   1.38888884    0.            0.         -202.27371216]
#  [   0.            1.38888884    0.         -159.73500061]
#  [   0.            0.            3.          -33.24699402]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.38888884 1.38888884 3.        ]
#   Scale factors: [1.38888884 1.38888884 3.        ]
#   Resampled shape: (400, 322, 216)
#   Resize factors: (0.48, 0.5962732919254659, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0555.nii.gz
#
# Processing: amos_0557.nii.gz
#   Original shape: (512, 152, 512)
#   Affine:
# [[   0.82029998    0.            0.         -222.26628113]
#  [   0.            1.09999847    0.          -73.48036194]
#  [   0.            0.            0.82029998 -215.43728638]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 167, 420)
#   Resize factors: (0.45714285714285713, 1.1497005988023952, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0557.nii.gz
#
# Processing: amos_0558.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -219.33927917]
#  [   0.            1.09999847    0.          -79.23073578]
#  [   0.            0.            0.82029998 -258.36425781]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0558.nii.gz
#
# Processing: amos_0570.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -165.32171631]
#  [   0.            1.1875        0.         -164.63539124]
#  [   0.            0.            3.         -117.58433533]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0570.nii.gz
#
# Processing: amos_0571.nii.gz
#   Original shape: (320, 258, 72)
#   Affine:
# [[   1.25          0.            0.         -180.71864319]
#  [   0.            1.25          0.         -158.34103394]
#  [   0.            0.            3.          -51.35328674]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.25 1.25 3.  ]
#   Scale factors: [1.25 1.25 3.  ]
#   Resampled shape: (400, 322, 216)
#   Resize factors: (0.48, 0.5962732919254659, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0571.nii.gz
#
# Processing: amos_0578.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -216.41227722]
#  [   0.            1.09999847    0.          -68.24849701]
#  [   0.            0.            0.82029998 -196.2902832 ]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0578.nii.gz
#
# Processing: amos_0580.nii.gz
#   Original shape: (320, 60, 320)
#   Affine:
# [[ 1.18747103e+00  2.09437590e-02  0.00000000e+00 -2.34293549e+02]
#  [-8.29024613e-03  2.99992371e+00  0.00000000e+00 -9.35699692e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.18750000e+00 -2.02547440e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.19576128 3.02086747 1.1875    ]
#   Scale factors: [1.19576128 3.02086747 1.1875    ]
#   Resampled shape: (383, 181, 380)
#   Resize factors: (0.5013054830287206, 1.0607734806629834, 0.5052631578947369)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0580.nii.gz
#
# Processing: amos_0582.nii.gz
#   Original shape: (320, 60, 320)
#   Affine:
# [[ 1.18749821e+00 -5.23597933e-03  0.00000000e+00 -1.86706299e+02]
#  [ 2.07257736e-03  2.99999237e+00  0.00000000e+00 -9.91650925e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.18750000e+00 -1.56764313e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.18957079 3.00522835 1.1875    ]
#   Scale factors: [1.18957079 3.00522835 1.1875    ]
#   Resampled shape: (381, 180, 380)
#   Resize factors: (0.5039370078740157, 1.0666666666666667, 0.5052631578947369)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0582.nii.gz
#
# Processing: amos_0583.nii.gz
#   Original shape: (320, 60, 320)
#   Affine:
# [[ 1.18748367e+00  1.57078672e-02  0.00000000e+00 -1.88357956e+02]
#  [-6.21770648e-03  2.99995446e+00  0.00000000e+00 -9.68096542e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.18750000e+00 -1.61342621e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.19370137 3.01566233 1.1875    ]
#   Scale factors: [1.19370137 3.01566233 1.1875    ]
#   Resampled shape: (382, 181, 380)
#   Resize factors: (0.5026178010471204, 1.0607734806629834, 0.5052631578947369)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0583.nii.gz
#
# Processing: amos_0584.nii.gz
#   Original shape: (288, 232, 72)
#   Affine:
# [[   1.38888884    0.            0.         -212.6109314 ]
#  [   0.            1.38888884    0.         -158.7819519 ]
#  [   0.            0.            3.         -112.90963745]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.38888884 1.38888884 3.        ]
#   Scale factors: [1.38888884 1.38888884 3.        ]
#   Resampled shape: (400, 322, 216)
#   Resize factors: (0.48, 0.5962732919254659, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0584.nii.gz
#
# Processing: amos_0585.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -166.40614319]
#  [   0.            1.1875        0.         -153.604599  ]
#  [   0.            0.            3.         -171.46385193]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0585.nii.gz
#
# Processing: amos_0586.nii.gz
#   Original shape: (260, 144, 320)
#   Affine:
# [[ 1.40629137e+00 -5.23595605e-03  0.00000000e+00 -2.20411591e+02]
#  [ 4.90890304e-03  1.49998486e+00  0.00000000e+00 -7.24297943e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.40629995e+00 -2.69379028e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.41120027 1.50522082 1.40629995]
#   Scale factors: [1.41120027 1.50522082 1.40629995]
#   Resampled shape: (367, 217, 450)
#   Resize factors: (0.5231607629427792, 0.8847926267281107, 0.4266666666666667)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0586.nii.gz
#
# Processing: amos_0587.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -205.61062622]
#  [   0.            1.1875        0.         -164.77601624]
#  [   0.            0.            3.          -75.46385193]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0587.nii.gz
#
# Processing: amos_0588.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -197.87628174]
#  [   0.            1.09999847    0.          -80.20674133]
#  [   0.            0.            0.82029998 -209.58328247]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0588.nii.gz
#
# Processing: amos_0589.nii.gz
#   Original shape: (320, 60, 320)
#   Affine:
# [[ 1.18749273e+00 -1.04894871e-02 -2.13716589e-06 -1.72698624e+02]
#  [ 4.15208470e-03  2.99998450e+00  6.11200172e-04 -9.92653732e+01]
#  [ 9.58597438e-11 -1.54409581e-03  1.18749988e+00 -1.61634125e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.19164481 3.01201809 1.18811322]
#   Scale factors: [1.19164481 3.01201809 1.18811322]
#   Resampled shape: (381, 181, 380)
#   Resize factors: (0.5039370078740157, 1.0607734806629834, 0.5052631578947369)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0589.nii.gz
#
# Processing: amos_0590.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -186.20727539]
#  [   0.            1.1000061     0.          -59.72001648]
#  [   0.            0.            0.82029998 -194.88328552]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.1000061  0.82029998]
#   Scale factors: [0.82029998 1.1000061  0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0590.nii.gz
#
# Processing: amos_0591.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -176.66055298]
#  [   0.            1.1875        0.         -151.59246826]
#  [   0.            0.            3.         -111.40148163]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0591.nii.gz
#
# Processing: amos_0592.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -189.10528564]
#  [   0.            1.09999847    0.          -74.35273743]
#  [   0.            0.            0.82029998 -244.72927856]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0592.nii.gz
#
# Processing: amos_0593.nii.gz
#   Original shape: (576, 468, 72)
#   Affine:
# [[   0.69444442    0.            0.         -199.30554199]
#  [   0.            0.69444442    0.         -161.80554199]
#  [   0.            0.            3.          -52.5       ]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.69444442 0.69444442 3.        ]
#   Scale factors: [0.69444442 0.69444442 3.        ]
#   Resampled shape: (400, 325, 216)
#   Resize factors: (0.48, 0.5907692307692308, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0593.nii.gz
#
# Processing: amos_0594.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -218.36328125]
#  [   0.            1.09999847    0.          -77.27973938]
#  [   0.            0.            0.82029998 -222.26628113]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.09999847 0.82029998]
#   Scale factors: [0.82029998 1.09999847 0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0594.nii.gz
#
# Processing: amos_0595.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -190.88786316]
#  [   0.            1.1875        0.         -164.6993103 ]
#  [   0.            0.            3.          -67.41566467]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0595.nii.gz
#
# Processing: amos_0596.nii.gz
#   Original shape: (512, 168, 512)
#   Affine:
# [[   0.82029998    0.            0.         -236.90028381]
#  [   0.            1.1000061     0.          -88.98861694]
#  [   0.            0.            0.82029998 -141.2902832 ]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [0.82029998 1.1000061  0.82029998]
#   Scale factors: [0.82029998 1.1000061  0.82029998]
#   Resampled shape: (420, 185, 420)
#   Resize factors: (0.45714285714285713, 1.037837837837838, 0.45714285714285713)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0596.nii.gz
#
# Processing: amos_0597.nii.gz
#   Original shape: (320, 60, 320)
#   Affine:
# [[ 1.18735349e+00 -4.71218936e-02  0.00000000e+00 -1.78386322e+02]
#  [ 1.86524391e-02  2.99962616e+00  0.00000000e+00 -9.67081604e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.18750000e+00 -1.36185989e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#   Original voxel spacing: [1.20600593 3.04674805 1.1875    ]
#   Scale factors: [1.20600593 3.04674805 1.1875    ]
#   Resampled shape: (386, 183, 380)
#   Resize factors: (0.49740932642487046, 1.0491803278688525, 0.5052631578947369)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0597.nii.gz
#
# Processing: amos_0599.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -188.50514221]
#  [   0.            1.1875        0.         -131.73602295]
#  [   0.            0.            3.          -56.1385498 ]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0599.nii.gz
#
# Processing: amos_0600.nii.gz
#   Original shape: (320, 260, 72)
#   Affine:
# [[   1.1875        0.            0.         -187.29748535]
#  [   0.            1.1875        0.         -164.71209717]
#  [   0.            0.            3.         -119.41566467]
#  [   0.            0.            0.            1.        ]]
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: (0.5052631578947369, 0.6213592233009708, 0.8888888888888888)
#   Final shape: (192, 192, 192)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/amos_0600.nii.gz
#
# Processing complete!

# %%
# Resample and reshape AMOS22 MRI dataset to 1x1x1 mm voxel size and target shape using SimpleITK

import os
import numpy as np
import SimpleITK as sitk
from pathlib import Path

# Define paths
input_dir = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTr/")
output_dir = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/")
output_dir.mkdir(parents=True, exist_ok=True)

# Define target voxel spacing and shape
target_spacing = (1.0, 1.0, 1.0)  # mm (x, y, z)
target_shape = (192, 192, 192)    # voxels (x, y, z)

def resample_to_spacing(img, target_spacing, is_label=False):
    """Resample image to the target voxel spacing."""
    original_spacing = img.GetSpacing()
    original_size = img.GetSize()
    new_size = [
        int(round(osz * (osp / tsp)))
        for osz, osp, tsp in zip(original_size, original_spacing, target_spacing)
    ]
    
    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(target_spacing)
    resampler.SetSize(new_size)
    resampler.SetOutputDirection(img.GetDirection())
    resampler.SetOutputOrigin(img.GetOrigin())
    resampler.SetDefaultPixelValue(img.GetPixelIDValue())
    
    img_resampled = resampler.Execute(img)
    return img_resampled

def resize_to_target_shape(img, target_shape, is_label=False):
    """Resize image to the target shape by adjusting spacing."""
    current_size = img.GetSize()
    current_spacing = img.GetSpacing()
    new_spacing = [
        csp * (csz / tsz)
        for csp, csz, tsz in zip(current_spacing, current_size, target_shape)
    ]
    
    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(new_spacing)
    resampler.SetSize(target_shape)
    resampler.SetOutputDirection(img.GetDirection())
    resampler.SetOutputOrigin(img.GetOrigin())
    resampler.SetDefaultPixelValue(img.GetPixelIDValue())
    
    img_resized = resampler.Execute(img)
    return img_resized

# Loop over all NIfTI files in the input directory
for filename in sorted(input_dir.glob("*.nii*")):
    print(f"Processing: {filename.name}")
    
    # Load the NIfTI file using SimpleITK
    img = sitk.ReadImage(str(filename))
    
    # Print some info
    print(f"  Original size: {img.GetSize()}")
    print(f"  Original spacing: {img.GetSpacing()}")
    
    # Step 1: Resample to isotropic spacing
    img_resampled = resample_to_spacing(img, target_spacing)
    print(f"  Resampled size: {img_resampled.GetSize()}")
    print(f"  Resampled spacing: {img_resampled.GetSpacing()}")
    
    # Step 2: Resize to target shape
    img_resized = resize_to_target_shape(img_resampled, target_shape)
    print(f"  Resized size: {img_resized.GetSize()}")
    print(f"  Resized spacing: {img_resized.GetSpacing()}")
    
    # Save the processed image
    output_path = output_dir / filename.name
    sitk.WriteImage(img_resized, str(output_path))
    print(f"  Saved to: {output_path}\n")

print("✅ Processing complete!")
# Out:
# Processing: amos_0507.nii.gz
#   Original size: (320, 290, 72)
#   Original spacing: (1.1875, 1.1875, 2.5)
#   Resampled size: (380, 344, 180)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.7916666666666667, 0.9375)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0507.nii.gz
#
# Processing: amos_0508.nii.gz
#   Original size: (260, 80, 320)
#   Original spacing: (1.40625, 1.5, 1.40625)
#   Resampled size: (366, 120, 450)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.90625, 0.625, 2.34375)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0508.nii.gz
#
# Processing: amos_0510.nii.gz
#   Original size: (260, 104, 320)
#   Original spacing: (1.40625, 1.5, 1.40625)
#   Resampled size: (366, 156, 450)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.90625, 0.8125, 2.34375)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0510.nii.gz
#
# Processing: amos_0514.nii.gz
#   Original size: (260, 112, 320)
#   Original spacing: (1.40625, 1.5, 1.40625)
#   Resampled size: (366, 168, 450)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.90625, 0.875, 2.34375)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0514.nii.gz
#
# Processing: amos_0517.nii.gz
#   Original size: (400, 400, 115)
#   Original spacing: (1.0, 1.0, 2.0)
#   Resampled size: (400, 400, 230)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 2.0833333333333335, 1.1979166666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0517.nii.gz
#
# Processing: amos_0518.nii.gz
#   Original size: (400, 120, 400)
#   Original spacing: (1.0, 2.0, 1.0)
#   Resampled size: (400, 240, 400)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.25, 2.0833333333333335)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0518.nii.gz
#
# Processing: amos_0522.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.375, 1.375, 3.0)
#   Resampled size: (440, 358, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.2916666666666665, 1.8645833333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0522.nii.gz
#
# Processing: amos_0530.nii.gz
#   Original size: (320, 290, 64)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 344, 192)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.7916666666666667, 1.0)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0530.nii.gz
#
# Processing: amos_0532.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.3125, 1.3125, 3.0)
#   Resampled size: (420, 341, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 1.7760416666666667, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0532.nii.gz
#
# Processing: amos_0538.nii.gz
#   Original size: (320, 260, 64)
#   Original spacing: (1.3125, 1.3125, 3.0)
#   Resampled size: (420, 341, 192)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 1.7760416666666667, 1.0)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0538.nii.gz
#
# Processing: amos_0540.nii.gz
#   Original size: (192, 192, 100)
#   Original spacing: (1.953125, 1.953125, 2.0)
#   Resampled size: (375, 375, 200)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.953125, 1.953125, 1.0416666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0540.nii.gz
#
# Processing: amos_0541.nii.gz
#   Original size: (320, 290, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 344, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.7916666666666667, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0541.nii.gz
#
# Processing: amos_0548.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0548.nii.gz
#
# Processing: amos_0551.nii.gz
#   Original size: (576, 468, 72)
#   Original spacing: (0.6944444179534912, 0.6944444179534912, 3.0)
#   Resampled size: (400, 325, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.6927083333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0551.nii.gz
#
# Processing: amos_0554.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0554.nii.gz
#
# Processing: amos_0555.nii.gz
#   Original size: (288, 232, 72)
#   Original spacing: (1.3888888359069824, 1.3888888359069824, 3.0)
#   Resampled size: (400, 322, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.6770833333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0555.nii.gz
#
# Processing: amos_0557.nii.gz
#   Original size: (512, 152, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 167, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.8697916666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0557.nii.gz
#
# Processing: amos_0558.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0558.nii.gz
#
# Processing: amos_0570.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0570.nii.gz
#
# Processing: amos_0571.nii.gz
#   Original size: (320, 258, 72)
#   Original spacing: (1.25, 1.25, 3.0)
#   Resampled size: (400, 322, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.6770833333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0571.nii.gz
#
# Processing: amos_0578.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0578.nii.gz
#
# Processing: amos_0580.nii.gz
#   Original size: (320, 60, 320)
#   Original spacing: (1.1875, 3.0, 1.1875)
#   Resampled size: (380, 180, 380)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 0.9375, 1.9791666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0580.nii.gz
#
# Processing: amos_0582.nii.gz
#   Original size: (320, 60, 320)
#   Original spacing: (1.1875, 3.0, 1.1875)
#   Resampled size: (380, 180, 380)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 0.9375, 1.9791666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0582.nii.gz
#
# Processing: amos_0583.nii.gz
#   Original size: (320, 60, 320)
#   Original spacing: (1.1875, 3.0, 1.1875)
#   Resampled size: (380, 180, 380)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 0.9375, 1.9791666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0583.nii.gz
#
# Processing: amos_0584.nii.gz
#   Original size: (288, 232, 72)
#   Original spacing: (1.3888888359069824, 1.3888888359069824, 3.0)
#   Resampled size: (400, 322, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.6770833333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0584.nii.gz
#
# Processing: amos_0585.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0585.nii.gz
#
# Processing: amos_0586.nii.gz
#   Original size: (260, 144, 320)
#   Original spacing: (1.4062999486923218, 1.5, 1.4062999486923218)
#   Resampled size: (366, 216, 450)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.90625, 1.125, 2.34375)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0586.nii.gz
#
# Processing: amos_0587.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0587.nii.gz
#
# Processing: amos_0588.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0588.nii.gz
#
# Processing: amos_0589.nii.gz
#   Original size: (320, 60, 320)
#   Original spacing: (1.1875, 3.0, 1.1875)
#   Resampled size: (380, 180, 380)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 0.9375, 1.9791666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0589.nii.gz
#
# Processing: amos_0590.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0590.nii.gz
#
# Processing: amos_0591.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0591.nii.gz
#
# Processing: amos_0592.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0592.nii.gz
#
# Processing: amos_0593.nii.gz
#   Original size: (576, 468, 72)
#   Original spacing: (0.6944444179534912, 0.6944444179534912, 3.0)
#   Resampled size: (400, 325, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.0833333333333335, 1.6927083333333333, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0593.nii.gz
#
# Processing: amos_0594.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0594.nii.gz
#
# Processing: amos_0595.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0595.nii.gz
#
# Processing: amos_0596.nii.gz
#   Original size: (512, 168, 512)
#   Original spacing: (0.8202999830245972, 1.100000023841858, 0.8202999830245972)
#   Resampled size: (420, 185, 420)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (2.1875, 0.9635416666666666, 2.1875)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0596.nii.gz
#
# Processing: amos_0597.nii.gz
#   Original size: (320, 60, 320)
#   Original spacing: (1.1875, 3.0, 1.1875)
#   Resampled size: (380, 180, 380)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 0.9375, 1.9791666666666667)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0597.nii.gz
#
# Processing: amos_0599.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0599.nii.gz
#
# Processing: amos_0600.nii.gz
#   Original size: (320, 260, 72)
#   Original spacing: (1.1875, 1.1875, 3.0)
#   Resampled size: (380, 309, 216)
#   Resampled spacing: (1.0, 1.0, 1.0)
#   Resized size: (192, 192, 192)
#   Resized spacing: (1.9791666666666667, 1.609375, 1.125)
#   Saved to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_itk/imagesTr/amos_0600.nii.gz
#
# ✅ Processing complete!

# %%
import os
from pathlib import Path
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

# Define the folders
original_dir = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTr/")
resampled_dir = Path("/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled/imagesTr/")

# Find all NIfTI files in both directories
original_files = sorted(original_dir.glob("*.nii*"))
resampled_files = sorted(resampled_dir.glob("*.nii*"))

# Create a mapping from filename to resampled file
resampled_map = {f.name: f for f in resampled_files}

# Loop through each original file and compare with resampled
for original_file in original_files:
    filename = original_file.name
    if filename not in resampled_map:
        print(f"❌ Skipping {filename} (no matching resampled file)")
        continue
    
    resampled_file = resampled_map[filename]
    print(f"✅ Visualizing {filename}")
    
    # Load the images
    original_img = sitk.ReadImage(str(original_file))
    resampled_img = sitk.ReadImage(str(resampled_file))
    
    # Convert to numpy arrays
    original_np = sitk.GetArrayFromImage(original_img)   # (Z, Y, X)
    resampled_np = sitk.GetArrayFromImage(resampled_img)
    
    # Choose middle slice (Z-axis)
    original_mid_slice = original_np.shape[0] // 2
    resampled_mid_slice = resampled_np.shape[0] // 2
    
    # Plot side-by-side
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))
    axs[0].imshow(original_np[original_mid_slice, :, :], cmap='gray')
    axs[0].set_title(
        f"Original: {filename}\nShape: {original_np.shape}, Spacing: {original_img.GetSpacing()}"
    )
    axs[0].axis('off')
    
    axs[1].imshow(resampled_np[resampled_mid_slice, :, :], cmap='gray')
    axs[1].set_title(
        f"Resampled: {filename}\nShape: {resampled_np.shape}, Spacing: {resampled_img.GetSpacing()}"
    )
    axs[1].axis('off')
    
    plt.suptitle(f"Comparison: {filename}")
    plt.show()

# %% [markdown]
# AMOS Resample

# %%
import numpy as np
import os
import nibabel as nib
from scipy.ndimage import zoom

# Define paths
input_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/imagesTs/"
output_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/"

labels_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri/labelsTs/"
labels_out_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/labelsTs/"

# Ensure output directories exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(labels_out_dir, exist_ok=True)

# Target voxel spacing and shape
target_spacing = [1.0, 1.0, 1.0]  # mm
target_shape = [192, 192, 192]

# Process each image
for filename in sorted(os.listdir(input_dir)):
    if filename.endswith(".nii") or filename.endswith(".nii.gz"):
        print(f"Processing: {filename}")

        # Load image
        img_path = os.path.join(input_dir, filename)
        img_nii = nib.load(img_path)
        img_data = img_nii.get_fdata()
        img_affine = img_nii.affine

        # Calculate voxel spacing from affine
        voxel_spacing = np.sqrt((img_affine[:3, :3] ** 2).sum(axis=0))
        print(f"  Original shape: {img_data.shape}")
        print(f"  Original voxel spacing: {voxel_spacing}")

        # Compute scale factors
        scale_factors = voxel_spacing / target_spacing
        print(f"  Scale factors: {scale_factors}")

        # Resample image to isotropic spacing
        img_resampled = zoom(img_data, scale_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Resampled shape: {img_resampled.shape}")

        # Compute resize factors to target shape
        resize_factors = [
            target_shape[i] / img_resampled.shape[i] for i in range(3)
        ]
        print(f"  Resize factors: {resize_factors}")

        # Resize to target shape
        img_resized = zoom(img_resampled, resize_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Final image shape: {img_resized.shape}")

        # Save resampled image
        new_affine = np.copy(img_affine)
        new_affine[:3, :3] = np.diag(target_spacing)
        out_img = nib.Nifti1Image(img_resized.astype(np.float32), new_affine)
        out_path = os.path.join(output_dir, filename)
        nib.save(out_img, out_path)
        print(f"  Saved image to: {out_path}")

        # Process corresponding label
        label_path = os.path.join(labels_dir, filename)
        if os.path.exists(label_path):
            print(f"  Processing label: {filename}")
            label_nii = nib.load(label_path)
            label_data = label_nii.get_fdata()

            # Resample label with nearest neighbor interpolation
            label_resampled = zoom(label_data, scale_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Label resampled shape: {label_resampled.shape}")

            # Resize label to target shape
            label_resized = zoom(label_resampled, resize_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Final label shape: {label_resized.shape}")

            # Save resampled label
            label_out_img = nib.Nifti1Image(label_resized.astype(np.uint8), new_affine)
            label_out_path = os.path.join(labels_out_dir, filename)
            nib.save(label_out_img, label_out_path)
            print(f"  Saved label to: {label_out_path}")
        else:
            print(f"  ⚠️ Label file not found for {filename} — skipping label processing.")

        print()

print("✅ All images and labels have been processed.")
# Out:
# Processing: amos_0500.nii.gz
#   Original shape: (512, 512, 246)
#   Original voxel spacing: [0.67578125 0.67578125 2.        ]
#   Scale factors: [0.67578125 0.67578125 2.        ]
#   Resampled shape: (346, 346, 492)
#   Resize factors: [0.5549132947976878, 0.5549132947976878, 0.3902439024390244]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0500.nii.gz
#   ⚠️ Label file not found for amos_0500.nii.gz — skipping label processing.
#
# Processing: amos_0501.nii.gz
#   Original shape: (1024, 1024, 48)
#   Original voxel spacing: [0.39062501 0.39062499 5.00000268]
#   Scale factors: [0.39062501 0.39062499 5.00000268]
#   Resampled shape: (400, 400, 240)
#   Resize factors: [0.48, 0.48, 0.8]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0501.nii.gz
#   ⚠️ Label file not found for amos_0501.nii.gz — skipping label processing.
#
# Processing: amos_0502.nii.gz
#   Original shape: (1024, 1024, 40)
#   Original voxel spacing: [0.36621092 0.36621095 5.79587791]
#   Scale factors: [0.36621092 0.36621095 5.79587791]
#   Resampled shape: (375, 375, 232)
#   Resize factors: [0.512, 0.512, 0.8275862068965517]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0502.nii.gz
#   ⚠️ Label file not found for amos_0502.nii.gz — skipping label processing.
#
# Processing: amos_0503.nii.gz
#   Original shape: (576, 95, 576)
#   Original voxel spacing: [0.86805561 1.99999885 0.8680556 ]
#   Scale factors: [0.86805561 1.99999885 0.8680556 ]
#   Resampled shape: (500, 190, 500)
#   Resize factors: [0.384, 1.0105263157894737, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0503.nii.gz
#   ⚠️ Label file not found for amos_0503.nii.gz — skipping label processing.
#
# Processing: amos_0504.nii.gz
#   Original shape: (384, 95, 384)
#   Original voxel spacing: [0.98958332 1.74999866 0.98958332]
#   Scale factors: [0.98958332 1.74999866 0.98958332]
#   Resampled shape: (380, 166, 380)
#   Resize factors: [0.5052631578947369, 1.1566265060240963, 0.5052631578947369]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0504.nii.gz
#   ⚠️ Label file not found for amos_0504.nii.gz — skipping label processing.
#
# Processing: amos_0506.nii.gz
#   Original shape: (480, 80, 480)
#   Original voxel spacing: [0.9375     2.00000182 0.93749999]
#   Scale factors: [0.9375     2.00000182 0.93749999]
#   Resampled shape: (450, 160, 450)
#   Resize factors: [0.4266666666666667, 1.2, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0506.nii.gz
#   ⚠️ Label file not found for amos_0506.nii.gz — skipping label processing.
#
# Processing: amos_0509.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [0.99999999 1.00000001 2.00000255]
#   Scale factors: [0.99999999 1.00000001 2.00000255]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0509.nii.gz
#   ⚠️ Label file not found for amos_0509.nii.gz — skipping label processing.
#
# Processing: amos_0511.nii.gz
#   Original shape: (432, 80, 432)
#   Original voxel spacing: [0.92592592 3.00000737 0.92592588]
#   Scale factors: [0.92592592 3.00000737 0.92592588]
#   Resampled shape: (400, 240, 400)
#   Resize factors: [0.48, 0.8, 0.48]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0511.nii.gz
#   ⚠️ Label file not found for amos_0511.nii.gz — skipping label processing.
#
# Processing: amos_0512.nii.gz
#   Original shape: (336, 336, 85)
#   Original voxel spacing: [1.11607146 1.11607146 2.99999995]
#   Scale factors: [1.11607146 1.11607146 2.99999995]
#   Resampled shape: (375, 375, 255)
#   Resize factors: [0.512, 0.512, 0.7529411764705882]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0512.nii.gz
#   ⚠️ Label file not found for amos_0512.nii.gz — skipping label processing.
#
# Processing: amos_0513.nii.gz
#   Original shape: (1024, 1024, 70)
#   Original voxel spacing: [0.39062499 0.390625   2.49999961]
#   Scale factors: [0.39062499 0.390625   2.49999961]
#   Resampled shape: (400, 400, 175)
#   Resize factors: [0.48, 0.48, 1.0971428571428572]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0513.nii.gz
#   ⚠️ Label file not found for amos_0513.nii.gz — skipping label processing.
#
# Processing: amos_0515.nii.gz
#   Original shape: (260, 104, 320)
#   Original voxel spacing: [1.40625002 1.50000048 1.40625007]
#   Scale factors: [1.40625002 1.50000048 1.40625007]
#   Resampled shape: (366, 156, 450)
#   Resize factors: [0.5245901639344263, 1.2307692307692308, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0515.nii.gz
#   ⚠️ Label file not found for amos_0515.nii.gz — skipping label processing.
#
# Processing: amos_0516.nii.gz
#   Original shape: (480, 80, 480)
#   Original voxel spacing: [0.93749999 2.00000163 0.93750002]
#   Scale factors: [0.93749999 2.00000163 0.93750002]
#   Resampled shape: (450, 160, 450)
#   Resize factors: [0.4266666666666667, 1.2, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0516.nii.gz
#   ⚠️ Label file not found for amos_0516.nii.gz — skipping label processing.
#
# Processing: amos_0519.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [0.99999999 1.00000002 1.9999952 ]
#   Scale factors: [0.99999999 1.00000002 1.9999952 ]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0519.nii.gz
#   ⚠️ Label file not found for amos_0519.nii.gz — skipping label processing.
#
# Processing: amos_0520.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [1.00000003 1.00000002 1.99999717]
#   Scale factors: [1.00000003 1.00000002 1.99999717]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0520.nii.gz
#   ⚠️ Label file not found for amos_0520.nii.gz — skipping label processing.
#
# Processing: amos_0521.nii.gz
#   Original shape: (480, 100, 480)
#   Original voxel spacing: [0.95833329 2.00000121 0.95833331]
#   Scale factors: [0.95833329 2.00000121 0.95833331]
#   Resampled shape: (460, 200, 460)
#   Resize factors: [0.41739130434782606, 0.96, 0.41739130434782606]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0521.nii.gz
#   ⚠️ Label file not found for amos_0521.nii.gz — skipping label processing.
#
# Processing: amos_0523.nii.gz
#   Original shape: (432, 432, 74)
#   Original voxel spacing: [0.9259259  0.92592593 6.00000771]
#   Scale factors: [0.9259259  0.92592593 6.00000771]
#   Resampled shape: (400, 400, 444)
#   Resize factors: [0.48, 0.48, 0.43243243243243246]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0523.nii.gz
#   ⚠️ Label file not found for amos_0523.nii.gz — skipping label processing.
#
# Processing: amos_0524.nii.gz
#   Original shape: (512, 80, 512)
#   Original voxel spacing: [0.97656244 2.99999664 0.9765625 ]
#   Scale factors: [0.97656244 2.99999664 0.9765625 ]
#   Resampled shape: (500, 240, 500)
#   Resize factors: [0.384, 0.8, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0524.nii.gz
#   ⚠️ Label file not found for amos_0524.nii.gz — skipping label processing.
#
# Processing: amos_0525.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [0.99999996 1.         2.00000135]
#   Scale factors: [0.99999996 1.         2.00000135]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0525.nii.gz
#   ⚠️ Label file not found for amos_0525.nii.gz — skipping label processing.
#
# Processing: amos_0526.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [1.00000002 1.00000002 2.00000918]
#   Scale factors: [1.00000002 1.00000002 2.00000918]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0526.nii.gz
#   ⚠️ Label file not found for amos_0526.nii.gz — skipping label processing.
#
# Processing: amos_0527.nii.gz
#   Original shape: (400, 120, 400)
#   Original voxel spacing: [0.99999998 2.00000505 1.00000002]
#   Scale factors: [0.99999998 2.00000505 1.00000002]
#   Resampled shape: (400, 240, 400)
#   Resize factors: [0.48, 0.8, 0.48]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0527.nii.gz
#   ⚠️ Label file not found for amos_0527.nii.gz — skipping label processing.
#
# Processing: amos_0528.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [0.99999998 1.         2.00001829]
#   Scale factors: [0.99999998 1.         2.00001829]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0528.nii.gz
#   ⚠️ Label file not found for amos_0528.nii.gz — skipping label processing.
#
# Processing: amos_0529.nii.gz
#   Original shape: (512, 80, 512)
#   Original voxel spacing: [0.97656253 2.99999681 0.97656247]
#   Scale factors: [0.97656253 2.99999681 0.97656247]
#   Resampled shape: (500, 240, 500)
#   Resize factors: [0.384, 0.8, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0529.nii.gz
#   ⚠️ Label file not found for amos_0529.nii.gz — skipping label processing.
#
# Processing: amos_0531.nii.gz
#   Original shape: (512, 80, 512)
#   Original voxel spacing: [0.97656244 3.00001191 0.9765625 ]
#   Scale factors: [0.97656244 3.00001191 0.9765625 ]
#   Resampled shape: (500, 240, 500)
#   Resize factors: [0.384, 0.8, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0531.nii.gz
#   ⚠️ Label file not found for amos_0531.nii.gz — skipping label processing.
#
# Processing: amos_0533.nii.gz
#   Original shape: (400, 400, 100)
#   Original voxel spacing: [1.00000001 1.00000002 2.49999796]
#   Scale factors: [1.00000001 1.00000002 2.49999796]
#   Resampled shape: (400, 400, 250)
#   Resize factors: [0.48, 0.48, 0.768]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0533.nii.gz
#   ⚠️ Label file not found for amos_0533.nii.gz — skipping label processing.
#
# Processing: amos_0534.nii.gz
#   Original shape: (480, 80, 480)
#   Original voxel spacing: [0.93750003 2.         0.93750003]
#   Scale factors: [0.93750003 2.         0.93750003]
#   Resampled shape: (450, 160, 450)
#   Resize factors: [0.4266666666666667, 1.2, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0534.nii.gz
#   ⚠️ Label file not found for amos_0534.nii.gz — skipping label processing.
#
# Processing: amos_0535.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [1.00000002 1.         2.00000841]
#   Scale factors: [1.00000002 1.         2.00000841]
#   Resampled shape: (400, 400, 230)
#   Resize factors: [0.48, 0.48, 0.8347826086956521]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0535.nii.gz
#   ⚠️ Label file not found for amos_0535.nii.gz — skipping label processing.
#
# Processing: amos_0536.nii.gz
#   Original shape: (400, 400, 115)
#   Original voxel spacing: [1.         1.00000002 2.49999872]
#   Scale factors: [1.         1.00000002 2.49999872]
#   Resampled shape: (400, 400, 287)
#   Resize factors: [0.48, 0.48, 0.6689895470383276]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0536.nii.gz
#   ⚠️ Label file not found for amos_0536.nii.gz — skipping label processing.
#
# Processing: amos_0537.nii.gz
#   Original shape: (480, 80, 480)
#   Original voxel spacing: [0.93749999 2.00000113 0.93749999]
#   Scale factors: [0.93749999 2.00000113 0.93749999]
#   Resampled shape: (450, 160, 450)
#   Resize factors: [0.4266666666666667, 1.2, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0537.nii.gz
#   ⚠️ Label file not found for amos_0537.nii.gz — skipping label processing.
#
# Processing: amos_0539.nii.gz
#   Original shape: (400, 100, 400)
#   Original voxel spacing: [1.00000003 3.000003   1.00000002]
#   Scale factors: [1.00000003 3.000003   1.00000002]
#   Resampled shape: (400, 300, 400)
#   Resize factors: [0.48, 0.64, 0.48]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0539.nii.gz
#   ⚠️ Label file not found for amos_0539.nii.gz — skipping label processing.
#
# Processing: amos_0542.nii.gz
#   Original shape: (320, 260, 72)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0542.nii.gz
#   ⚠️ Label file not found for amos_0542.nii.gz — skipping label processing.
#
# Processing: amos_0543.nii.gz
#   Original shape: (320, 260, 80)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 240)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0543.nii.gz
#   ⚠️ Label file not found for amos_0543.nii.gz — skipping label processing.
#
# Processing: amos_0560.nii.gz
#   Original shape: (576, 468, 72)
#   Original voxel spacing: [0.69444442 0.69444442 3.        ]
#   Scale factors: [0.69444442 0.69444442 3.        ]
#   Resampled shape: (400, 325, 216)
#   Resize factors: [0.48, 0.5907692307692308, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0560.nii.gz
#   ⚠️ Label file not found for amos_0560.nii.gz — skipping label processing.
#
# Processing: amos_0564.nii.gz
#   Original shape: (320, 260, 72)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0564.nii.gz
#   ⚠️ Label file not found for amos_0564.nii.gz — skipping label processing.
#
# Processing: amos_0565.nii.gz
#   Original shape: (576, 468, 72)
#   Original voxel spacing: [0.69444442 0.69444442 3.        ]
#   Scale factors: [0.69444442 0.69444442 3.        ]
#   Resampled shape: (400, 325, 216)
#   Resize factors: [0.48, 0.5907692307692308, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0565.nii.gz
#   ⚠️ Label file not found for amos_0565.nii.gz — skipping label processing.
#
# Processing: amos_0566.nii.gz
#   Original shape: (288, 232, 72)
#   Original voxel spacing: [1.38888884 1.38888884 3.        ]
#   Scale factors: [1.38888884 1.38888884 3.        ]
#   Resampled shape: (400, 322, 216)
#   Resize factors: [0.48, 0.5962732919254659, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0566.nii.gz
#   ⚠️ Label file not found for amos_0566.nii.gz — skipping label processing.
#
# Processing: amos_0567.nii.gz
#   Original shape: (320, 60, 320)
#   Original voxel spacing: [1.18750002 2.99999694 1.1875    ]
#   Scale factors: [1.18750002 2.99999694 1.1875    ]
#   Resampled shape: (380, 180, 380)
#   Resize factors: [0.5052631578947369, 1.0666666666666667, 0.5052631578947369]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0567.nii.gz
#   ⚠️ Label file not found for amos_0567.nii.gz — skipping label processing.
#
# Processing: amos_0569.nii.gz
#   Original shape: (320, 260, 72)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0569.nii.gz
#   ⚠️ Label file not found for amos_0569.nii.gz — skipping label processing.
#
# Processing: amos_0574.nii.gz
#   Original shape: (320, 260, 72)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0574.nii.gz
#   ⚠️ Label file not found for amos_0574.nii.gz — skipping label processing.
#
# Processing: amos_0577.nii.gz
#   Original shape: (320, 260, 72)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 216)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0577.nii.gz
#   ⚠️ Label file not found for amos_0577.nii.gz — skipping label processing.
#
# Processing: amos_0579.nii.gz
#   Original shape: (320, 260, 64)
#   Original voxel spacing: [1.1875 1.1875 3.    ]
#   Scale factors: [1.1875 1.1875 3.    ]
#   Resampled shape: (380, 309, 192)
#   Resize factors: [0.5052631578947369, 0.6213592233009708, 1.0]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_mri_resampled_new/imagesTs/amos_0579.nii.gz
#   ⚠️ Label file not found for amos_0579.nii.gz — skipping label processing.
#
# ✅ All images and labels have been processed.

# %% [markdown]
# CHAOS Resample

# %%
import numpy as np
import os
import nibabel as nib
from scipy.ndimage import zoom

# Define paths
input_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/chaos/NIfTI_new/MR/images/"
output_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/"

labels_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/chaos/NIfTI_new/MR/labels/"
labels_out_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/"

# Ensure output directories exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(labels_out_dir, exist_ok=True)

# Target voxel spacing and shape
target_spacing = [1.0, 1.0, 1.0]  # mm
target_shape = [192, 192, 192]

# Process each image
for filename in sorted(os.listdir(input_dir)):
    if filename.endswith(".nii") or filename.endswith(".nii.gz"):
        print(f"Processing: {filename}")

        # Load image
        img_path = os.path.join(input_dir, filename)
        img_nii = nib.load(img_path)
        img_data = img_nii.get_fdata()
        img_affine = img_nii.affine

        # Calculate voxel spacing from affine
        voxel_spacing = np.sqrt((img_affine[:3, :3] ** 2).sum(axis=0))
        print(f"  Original shape: {img_data.shape}")
        print(f"  Original voxel spacing: {voxel_spacing}")

        # Compute scale factors
        scale_factors = voxel_spacing / target_spacing
        print(f"  Scale factors: {scale_factors}")

        # Resample image to isotropic spacing
        img_resampled = zoom(img_data, scale_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Resampled shape: {img_resampled.shape}")

        # Compute resize factors to target shape
        resize_factors = [
            target_shape[i] / img_resampled.shape[i] for i in range(3)
        ]
        print(f"  Resize factors: {resize_factors}")

        # Resize to target shape
        img_resized = zoom(img_resampled, resize_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Final image shape: {img_resized.shape}")

        # Save resampled image
        new_affine = np.copy(img_affine)
        new_affine[:3, :3] = np.diag(target_spacing)
        out_img = nib.Nifti1Image(img_resized.astype(np.float32), new_affine)
        out_path = os.path.join(output_dir, filename)
        nib.save(out_img, out_path)
        print(f"  Saved image to: {out_path}")

        # Process corresponding label
        label_path = os.path.join(labels_dir, filename)
        if os.path.exists(label_path):
            print(f"  Processing label: {filename}")
            label_nii = nib.load(label_path)
            label_data = label_nii.get_fdata()

            # Resample label with nearest neighbor interpolation
            label_resampled = zoom(label_data, scale_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Label resampled shape: {label_resampled.shape}")

            # Resize label to target shape
            label_resized = zoom(label_resampled, resize_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Final label shape: {label_resized.shape}")

            # Save resampled label
            label_out_img = nib.Nifti1Image(label_resized.astype(np.uint8), new_affine)
            label_out_path = os.path.join(labels_out_dir, filename)
            nib.save(label_out_img, label_out_path)
            print(f"  Saved label to: {label_out_path}")
        else:
            print(f"  ⚠️ Label file not found for {filename} — skipping label processing.")

        print()

print("✅ All images and labels have been processed.")
# Out:
# Processing: Patient_10_T1_IN.nii.gz
#   Original shape: (256, 256, 50)
#   Original voxel spacing: [1.89453125 1.89453125 5.5       ]
#   Scale factors: [1.89453125 1.89453125 5.5       ]
#   Resampled shape: (485, 485, 275)
#   Resize factors: [0.3958762886597938, 0.3958762886597938, 0.6981818181818182]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_10_T1_IN.nii.gz
#   Processing label: Patient_10_T1_IN.nii.gz
#   Label resampled shape: (485, 485, 275)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_10_T1_IN.nii.gz
#
# Processing: Patient_10_T2.nii.gz
#   Original shape: (256, 256, 36)
#   Original voxel spacing: [1.69921875 1.69921875 7.69999981]
#   Scale factors: [1.69921875 1.69921875 7.69999981]
#   Resampled shape: (435, 435, 277)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.6931407942238267]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_10_T2.nii.gz
#   Processing label: Patient_10_T2.nii.gz
#   Label resampled shape: (435, 435, 277)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_10_T2.nii.gz
#
# Processing: Patient_13_T1_IN.nii.gz
#   Original shape: (288, 288, 30)
#   Original voxel spacing: [1.44097221 1.44097221 9.        ]
#   Scale factors: [1.44097221 1.44097221 9.        ]
#   Resampled shape: (415, 415, 270)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_13_T1_IN.nii.gz
#   Processing label: Patient_13_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_13_T1_IN.nii.gz
#
# Processing: Patient_13_T2.nii.gz
#   Original shape: (320, 320, 30)
#   Original voxel spacing: [1.359375 1.359375 9.      ]
#   Scale factors: [1.359375 1.359375 9.      ]
#   Resampled shape: (435, 435, 270)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_13_T2.nii.gz
#   Processing label: Patient_13_T2.nii.gz
#   Label resampled shape: (435, 435, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_13_T2.nii.gz
#
# Processing: Patient_15_T1_IN.nii.gz
#   Original shape: (256, 256, 26)
#   Original voxel spacing: [1.69921875 1.69921875 9.        ]
#   Scale factors: [1.69921875 1.69921875 9.        ]
#   Resampled shape: (435, 435, 234)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_15_T1_IN.nii.gz
#   Processing label: Patient_15_T1_IN.nii.gz
#   Label resampled shape: (435, 435, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_15_T1_IN.nii.gz
#
# Processing: Patient_15_T2.nii.gz
#   Original shape: (256, 256, 26)
#   Original voxel spacing: [1.58203125 1.58203125 9.        ]
#   Scale factors: [1.58203125 1.58203125 9.        ]
#   Resampled shape: (405, 405, 234)
#   Resize factors: [0.4740740740740741, 0.4740740740740741, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_15_T2.nii.gz
#   Processing label: Patient_15_T2.nii.gz
#   Label resampled shape: (405, 405, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_15_T2.nii.gz
#
# Processing: Patient_19_T1_IN.nii.gz
#   Original shape: (288, 288, 30)
#   Original voxel spacing: [1.44097221 1.44097221 9.        ]
#   Scale factors: [1.44097221 1.44097221 9.        ]
#   Resampled shape: (415, 415, 270)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_19_T1_IN.nii.gz
#   Processing label: Patient_19_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_19_T1_IN.nii.gz
#
# Processing: Patient_19_T2.nii.gz
#   Original shape: (320, 320, 30)
#   Original voxel spacing: [1.359375 1.359375 9.      ]
#   Scale factors: [1.359375 1.359375 9.      ]
#   Resampled shape: (435, 435, 270)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_19_T2.nii.gz
#   Processing label: Patient_19_T2.nii.gz
#   Label resampled shape: (435, 435, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_19_T2.nii.gz
#
# Processing: Patient_1_T1_IN.nii.gz
#   Original shape: (256, 256, 35)
#   Original voxel spacing: [1.89453125 1.89453125 5.5       ]
#   Scale factors: [1.89453125 1.89453125 5.5       ]
#   Resampled shape: (485, 485, 192)
#   Resize factors: [0.3958762886597938, 0.3958762886597938, 1.0]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_1_T1_IN.nii.gz
#   Processing label: Patient_1_T1_IN.nii.gz
#   Label resampled shape: (485, 485, 192)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_1_T1_IN.nii.gz
#
# Processing: Patient_1_T2.nii.gz
#   Original shape: (256, 256, 36)
#   Original voxel spacing: [1.54296875 1.54296875 7.69999981]
#   Scale factors: [1.54296875 1.54296875 7.69999981]
#   Resampled shape: (395, 395, 277)
#   Resize factors: [0.4860759493670886, 0.4860759493670886, 0.6931407942238267]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_1_T2.nii.gz
#   Processing label: Patient_1_T2.nii.gz
#   Label resampled shape: (395, 395, 277)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_1_T2.nii.gz
#
# Processing: Patient_20_T1_IN.nii.gz
#   Original shape: (288, 288, 26)
#   Original voxel spacing: [1.44097221 1.44097221 9.        ]
#   Scale factors: [1.44097221 1.44097221 9.        ]
#   Resampled shape: (415, 415, 234)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_20_T1_IN.nii.gz
#   Processing label: Patient_20_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_20_T1_IN.nii.gz
#
# Processing: Patient_20_T2.nii.gz
#   Original shape: (320, 320, 26)
#   Original voxel spacing: [1.359375 1.359375 9.      ]
#   Scale factors: [1.359375 1.359375 9.      ]
#   Resampled shape: (435, 435, 234)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_20_T2.nii.gz
#   Processing label: Patient_20_T2.nii.gz
#   Label resampled shape: (435, 435, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_20_T2.nii.gz
#
# Processing: Patient_21_T1_IN.nii.gz
#   Original shape: (256, 256, 34)
#   Original voxel spacing: [1.81640632 1.81640626 8.00000017]
#   Scale factors: [1.81640632 1.81640626 8.00000017]
#   Resampled shape: (465, 465, 272)
#   Resize factors: [0.4129032258064516, 0.4129032258064516, 0.7058823529411765]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_21_T1_IN.nii.gz
#   Processing label: Patient_21_T1_IN.nii.gz
#   Label resampled shape: (465, 465, 272)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_21_T1_IN.nii.gz
#
# Processing: Patient_21_T2.nii.gz
#   Original shape: (256, 256, 31)
#   Original voxel spacing: [1.66015637 1.66015634 8.00000017]
#   Scale factors: [1.66015637 1.66015634 8.00000017]
#   Resampled shape: (425, 425, 248)
#   Resize factors: [0.45176470588235296, 0.45176470588235296, 0.7741935483870968]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_21_T2.nii.gz
#   Processing label: Patient_21_T2.nii.gz
#   Label resampled shape: (425, 425, 248)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_21_T2.nii.gz
#
# Processing: Patient_22_T1_IN.nii.gz
#   Original shape: (256, 256, 35)
#   Original voxel spacing: [2.03124992 2.03125005 9.0000001 ]
#   Scale factors: [2.03124992 2.03125005 9.0000001 ]
#   Resampled shape: (520, 520, 315)
#   Resize factors: [0.36923076923076925, 0.36923076923076925, 0.6095238095238096]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_22_T1_IN.nii.gz
#   Processing label: Patient_22_T1_IN.nii.gz
#   Label resampled shape: (520, 520, 315)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_22_T1_IN.nii.gz
#
# Processing: Patient_22_T2.nii.gz
#   Original shape: (256, 256, 33)
#   Original voxel spacing: [1.73828116 1.73828128 8.69999987]
#   Scale factors: [1.73828116 1.73828128 8.69999987]
#   Resampled shape: (445, 445, 287)
#   Resize factors: [0.4314606741573034, 0.4314606741573034, 0.6689895470383276]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_22_T2.nii.gz
#   Processing label: Patient_22_T2.nii.gz
#   Label resampled shape: (445, 445, 287)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_22_T2.nii.gz
#
# Processing: Patient_2_T1_IN.nii.gz
#   Original shape: (288, 288, 26)
#   Original voxel spacing: [1.4409722  1.44097221 9.00000063]
#   Scale factors: [1.4409722  1.44097221 9.00000063]
#   Resampled shape: (415, 415, 234)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_2_T1_IN.nii.gz
#   Processing label: Patient_2_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_2_T1_IN.nii.gz
#
# Processing: Patient_2_T2.nii.gz
#   Original shape: (320, 320, 26)
#   Original voxel spacing: [1.35937501 1.359375   9.00000063]
#   Scale factors: [1.35937501 1.359375   9.00000063]
#   Resampled shape: (435, 435, 234)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_2_T2.nii.gz
#   Processing label: Patient_2_T2.nii.gz
#   Label resampled shape: (435, 435, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_2_T2.nii.gz
#
# Processing: Patient_31_T1_IN.nii.gz
#   Original shape: (256, 256, 30)
#   Original voxel spacing: [1.69921875 1.69921874 8.99999958]
#   Scale factors: [1.69921875 1.69921874 8.99999958]
#   Resampled shape: (435, 435, 270)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_31_T1_IN.nii.gz
#   Processing label: Patient_31_T1_IN.nii.gz
#   Label resampled shape: (435, 435, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_31_T1_IN.nii.gz
#
# Processing: Patient_31_T2.nii.gz
#   Original shape: (256, 256, 29)
#   Original voxel spacing: [1.62109375 1.62109376 8.99999958]
#   Scale factors: [1.62109375 1.62109376 8.99999958]
#   Resampled shape: (415, 415, 261)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.735632183908046]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_31_T2.nii.gz
#   Processing label: Patient_31_T2.nii.gz
#   Label resampled shape: (415, 415, 261)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_31_T2.nii.gz
#
# Processing: Patient_32_T1_IN.nii.gz
#   Original shape: (256, 256, 33)
#   Original voxel spacing: [1.81640625 1.81640625 9.        ]
#   Scale factors: [1.81640625 1.81640625 9.        ]
#   Resampled shape: (465, 465, 297)
#   Resize factors: [0.4129032258064516, 0.4129032258064516, 0.6464646464646465]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_32_T1_IN.nii.gz
#   Processing label: Patient_32_T1_IN.nii.gz
#   Label resampled shape: (465, 465, 297)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_32_T1_IN.nii.gz
#
# Processing: Patient_32_T2.nii.gz
#   Original shape: (256, 256, 39)
#   Original voxel spacing: [1.81640625 1.81640625 9.        ]
#   Scale factors: [1.81640625 1.81640625 9.        ]
#   Resampled shape: (465, 465, 351)
#   Resize factors: [0.4129032258064516, 0.4129032258064516, 0.5470085470085471]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_32_T2.nii.gz
#   Processing label: Patient_32_T2.nii.gz
#   Label resampled shape: (465, 465, 351)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_32_T2.nii.gz
#
# Processing: Patient_33_T1_IN.nii.gz
#   Original shape: (256, 256, 33)
#   Original voxel spacing: [1.73828123 1.73828126 8.99999928]
#   Scale factors: [1.73828123 1.73828126 8.99999928]
#   Resampled shape: (445, 445, 297)
#   Resize factors: [0.4314606741573034, 0.4314606741573034, 0.6464646464646465]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_33_T1_IN.nii.gz
#   Processing label: Patient_33_T1_IN.nii.gz
#   Label resampled shape: (445, 445, 297)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_33_T1_IN.nii.gz
#
# Processing: Patient_33_T2.nii.gz
#   Original shape: (256, 256, 29)
#   Original voxel spacing: [1.73828123 1.73828126 8.99999928]
#   Scale factors: [1.73828123 1.73828126 8.99999928]
#   Resampled shape: (445, 445, 261)
#   Resize factors: [0.4314606741573034, 0.4314606741573034, 0.735632183908046]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_33_T2.nii.gz
#   Processing label: Patient_33_T2.nii.gz
#   Label resampled shape: (445, 445, 261)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_33_T2.nii.gz
#
# Processing: Patient_34_T1_IN.nii.gz
#   Original shape: (256, 256, 35)
#   Original voxel spacing: [1.73828125 1.73828125 5.5       ]
#   Scale factors: [1.73828125 1.73828125 5.5       ]
#   Resampled shape: (445, 445, 192)
#   Resize factors: [0.4314606741573034, 0.4314606741573034, 1.0]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_34_T1_IN.nii.gz
#   Processing label: Patient_34_T1_IN.nii.gz
#   Label resampled shape: (445, 445, 192)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_34_T1_IN.nii.gz
#
# Processing: Patient_34_T2.nii.gz
#   Original shape: (256, 256, 30)
#   Original voxel spacing: [1.73828125 1.73828125 8.80000019]
#   Scale factors: [1.73828125 1.73828125 8.80000019]
#   Resampled shape: (445, 445, 264)
#   Resize factors: [0.4314606741573034, 0.4314606741573034, 0.7272727272727273]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_34_T2.nii.gz
#   Processing label: Patient_34_T2.nii.gz
#   Label resampled shape: (445, 445, 264)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_34_T2.nii.gz
#
# Processing: Patient_36_T1_IN.nii.gz
#   Original shape: (256, 256, 38)
#   Original voxel spacing: [1.69921875 1.69921875 9.        ]
#   Scale factors: [1.69921875 1.69921875 9.        ]
#   Resampled shape: (435, 435, 342)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.5614035087719298]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_36_T1_IN.nii.gz
#   Processing label: Patient_36_T1_IN.nii.gz
#   Label resampled shape: (435, 435, 342)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_36_T1_IN.nii.gz
#
# Processing: Patient_36_T2.nii.gz
#   Original shape: (256, 256, 38)
#   Original voxel spacing: [1.62109375 1.62109375 9.        ]
#   Scale factors: [1.62109375 1.62109375 9.        ]
#   Resampled shape: (415, 415, 342)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.5614035087719298]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_36_T2.nii.gz
#   Processing label: Patient_36_T2.nii.gz
#   Label resampled shape: (415, 415, 342)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_36_T2.nii.gz
#
# Processing: Patient_37_T1_IN.nii.gz
#   Original shape: (256, 256, 30)
#   Original voxel spacing: [1.46484375 1.46484375 9.        ]
#   Scale factors: [1.46484375 1.46484375 9.        ]
#   Resampled shape: (375, 375, 270)
#   Resize factors: [0.512, 0.512, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_37_T1_IN.nii.gz
#   Processing label: Patient_37_T1_IN.nii.gz
#   Label resampled shape: (375, 375, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_37_T1_IN.nii.gz
#
# Processing: Patient_37_T2.nii.gz
#   Original shape: (256, 256, 32)
#   Original voxel spacing: [1.46484375 1.46484375 9.        ]
#   Scale factors: [1.46484375 1.46484375 9.        ]
#   Resampled shape: (375, 375, 288)
#   Resize factors: [0.512, 0.512, 0.6666666666666666]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_37_T2.nii.gz
#   Processing label: Patient_37_T2.nii.gz
#   Label resampled shape: (375, 375, 288)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_37_T2.nii.gz
#
# Processing: Patient_38_T1_IN.nii.gz
#   Original shape: (288, 288, 34)
#   Original voxel spacing: [1.44097221 1.44097221 9.        ]
#   Scale factors: [1.44097221 1.44097221 9.        ]
#   Resampled shape: (415, 415, 306)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.6274509803921569]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_38_T1_IN.nii.gz
#   Processing label: Patient_38_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 306)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_38_T1_IN.nii.gz
#
# Processing: Patient_38_T2.nii.gz
#   Original shape: (320, 320, 34)
#   Original voxel spacing: [1.359375 1.359375 9.      ]
#   Scale factors: [1.359375 1.359375 9.      ]
#   Resampled shape: (435, 435, 306)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.6274509803921569]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_38_T2.nii.gz
#   Processing label: Patient_38_T2.nii.gz
#   Label resampled shape: (435, 435, 306)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_38_T2.nii.gz
#
# Processing: Patient_39_T1_IN.nii.gz
#   Original shape: (256, 256, 26)
#   Original voxel spacing: [1.6992188  1.69921873 8.99999995]
#   Scale factors: [1.6992188  1.69921873 8.99999995]
#   Resampled shape: (435, 435, 234)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_39_T1_IN.nii.gz
#   Processing label: Patient_39_T1_IN.nii.gz
#   Label resampled shape: (435, 435, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_39_T1_IN.nii.gz
#
# Processing: Patient_39_T2.nii.gz
#   Original shape: (256, 256, 26)
#   Original voxel spacing: [1.58203125 1.58203123 8.99999995]
#   Scale factors: [1.58203125 1.58203123 8.99999995]
#   Resampled shape: (405, 405, 234)
#   Resize factors: [0.4740740740740741, 0.4740740740740741, 0.8205128205128205]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_39_T2.nii.gz
#   Processing label: Patient_39_T2.nii.gz
#   Label resampled shape: (405, 405, 234)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_39_T2.nii.gz
#
# Processing: Patient_3_T1_IN.nii.gz
#   Original shape: (288, 288, 30)
#   Original voxel spacing: [1.44097221 1.44097221 9.        ]
#   Scale factors: [1.44097221 1.44097221 9.        ]
#   Resampled shape: (415, 415, 270)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_3_T1_IN.nii.gz
#   Processing label: Patient_3_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_3_T1_IN.nii.gz
#
# Processing: Patient_3_T2.nii.gz
#   Original shape: (320, 320, 30)
#   Original voxel spacing: [1.359375 1.359375 9.      ]
#   Scale factors: [1.359375 1.359375 9.      ]
#   Resampled shape: (435, 435, 270)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_3_T2.nii.gz
#   Processing label: Patient_3_T2.nii.gz
#   Label resampled shape: (435, 435, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_3_T2.nii.gz
#
# Processing: Patient_5_T1_IN.nii.gz
#   Original shape: (256, 256, 30)
#   Original voxel spacing: [1.69921875 1.69921875 9.        ]
#   Scale factors: [1.69921875 1.69921875 9.        ]
#   Resampled shape: (435, 435, 270)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_5_T1_IN.nii.gz
#   Processing label: Patient_5_T1_IN.nii.gz
#   Label resampled shape: (435, 435, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_5_T1_IN.nii.gz
#
# Processing: Patient_5_T2.nii.gz
#   Original shape: (256, 256, 30)
#   Original voxel spacing: [1.66015625 1.66015625 9.        ]
#   Scale factors: [1.66015625 1.66015625 9.        ]
#   Resampled shape: (425, 425, 270)
#   Resize factors: [0.45176470588235296, 0.45176470588235296, 0.7111111111111111]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_5_T2.nii.gz
#   Processing label: Patient_5_T2.nii.gz
#   Label resampled shape: (425, 425, 270)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_5_T2.nii.gz
#
# Processing: Patient_8_T1_IN.nii.gz
#   Original shape: (288, 288, 36)
#   Original voxel spacing: [1.44097221 1.44097221 6.        ]
#   Scale factors: [1.44097221 1.44097221 6.        ]
#   Resampled shape: (415, 415, 216)
#   Resize factors: [0.46265060240963857, 0.46265060240963857, 0.8888888888888888]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_8_T1_IN.nii.gz
#   Processing label: Patient_8_T1_IN.nii.gz
#   Label resampled shape: (415, 415, 216)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_8_T1_IN.nii.gz
#
# Processing: Patient_8_T2.nii.gz
#   Original shape: (288, 288, 32)
#   Original voxel spacing: [1.40625    1.40625    7.99999952]
#   Scale factors: [1.40625    1.40625    7.99999952]
#   Resampled shape: (405, 405, 256)
#   Resize factors: [0.4740740740740741, 0.4740740740740741, 0.75]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/images/Patient_8_T2.nii.gz
#   Processing label: Patient_8_T2.nii.gz
#   Label resampled shape: (405, 405, 256)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/chaos/labels/Patient_8_T2.nii.gz
#
# ✅ All images and labels have been processed.

# %% [markdown]
# **CT AMOS Resample**

# %%
import numpy as np
import os
import nibabel as nib
from scipy.ndimage import zoom

# Define paths (update these to your actual CT data locations)
input_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_ct/images"
output_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images"

labels_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/amos22_ct/labels"
labels_out_dir = "/Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels"

# Ensure output directories exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(labels_out_dir, exist_ok=True)

# Target voxel spacing and shape
target_spacing = [1.0, 1.0, 1.0]  # mm
target_shape = [192, 192, 192]

def preprocess_ct(image):
    """Preprocess CT image with appropriate window settings."""
    window_min, window_max = -160, 240  # Typical abdominal window
    image = np.clip(image, window_min, window_max)
    image = (image - window_min) / (window_max - window_min)
    return image

# Process each image
for filename in sorted(os.listdir(input_dir)):
    if filename.endswith(".nii") or filename.endswith(".nii.gz"):
        print(f"Processing: {filename}")

        # Load image
        img_path = os.path.join(input_dir, filename)
        img_nii = nib.load(img_path)
        img_data = img_nii.get_fdata()
        img_affine = img_nii.affine

        # Calculate voxel spacing from affine
        voxel_spacing = np.sqrt((img_affine[:3, :3] ** 2).sum(axis=0))
        print(f"  Original shape: {img_data.shape}")
        print(f"  Original voxel spacing: {voxel_spacing}")

        # Compute scale factors
        scale_factors = voxel_spacing / target_spacing
        print(f"  Scale factors: {scale_factors}")

        # Resample image to isotropic spacing
        img_resampled = zoom(img_data, scale_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Resampled shape: {img_resampled.shape}")

        # Compute resize factors to target shape
        resize_factors = [
            target_shape[i] / img_resampled.shape[i] for i in range(3)
        ]
        print(f"  Resize factors: {resize_factors}")

        # Resize to target shape
        img_resized = zoom(img_resampled, resize_factors, order=3, mode='nearest', prefilter=False)
        print(f"  Final image shape: {img_resized.shape}")

        # --- CT-specific preprocessing ---
        # img_resized = preprocess_ct(img_resized)

        # Save resampled image
        new_affine = np.copy(img_affine)
        new_affine[:3, :3] = np.diag(target_spacing)
        out_img = nib.Nifti1Image(img_resized.astype(np.float32), new_affine)
        out_path = os.path.join(output_dir, filename)
        nib.save(out_img, out_path)
        print(f"  Saved image to: {out_path}")

        # Process corresponding label
        label_path = os.path.join(labels_dir, filename)
        if os.path.exists(label_path):
            print(f"  Processing label: {filename}")
            label_nii = nib.load(label_path)
            label_data = label_nii.get_fdata()

            # Resample label with nearest neighbor interpolation
            label_resampled = zoom(label_data, scale_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Label resampled shape: {label_resampled.shape}")

            # Resize label to target shape
            label_resized = zoom(label_resampled, resize_factors, order=0, mode='nearest', prefilter=False)
            print(f"  Final label shape: {label_resized.shape}")

            # Save resampled label
            label_out_img = nib.Nifti1Image(label_resized.astype(np.uint8), new_affine)
            label_out_path = os.path.join(labels_out_dir, filename)
            nib.save(label_out_img, label_out_path)
            print(f"  Saved label to: {label_out_path}")
        else:
            print(f"  ⚠️ Label file not found for {filename} — skipping label processing.")

        print()

print("✅ All CT images and labels have been processed.")
# Out:
# Processing: amos_0001.nii.gz
#   Original shape: (768, 768, 90)
#   Original voxel spacing: [0.5703125 0.5703125 5.       ]
#   Scale factors: [0.5703125 0.5703125 5.       ]
#   Resampled shape: (438, 438, 450)
#   Resize factors: [0.4383561643835616, 0.4383561643835616, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0001.nii.gz
#   Processing label: amos_0001.nii.gz
#   Label resampled shape: (438, 438, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0001.nii.gz
#
# Processing: amos_0004.nii.gz
#   Original shape: (512, 512, 78)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 390)
#   Resize factors: [0.48, 0.48, 0.49230769230769234]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0004.nii.gz
#   Processing label: amos_0004.nii.gz
#   Label resampled shape: (400, 400, 390)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0004.nii.gz
#
# Processing: amos_0005.nii.gz
#   Original shape: (768, 768, 80)
#   Original voxel spacing: [0.56901044 0.56901044 5.        ]
#   Scale factors: [0.56901044 0.56901044 5.        ]
#   Resampled shape: (437, 437, 400)
#   Resize factors: [0.43935926773455375, 0.43935926773455375, 0.48]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0005.nii.gz
#   Processing label: amos_0005.nii.gz
#   Label resampled shape: (437, 437, 400)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0005.nii.gz
#
# Processing: amos_0006.nii.gz
#   Original shape: (512, 512, 99)
#   Original voxel spacing: [0.83499998 0.83499998 5.        ]
#   Scale factors: [0.83499998 0.83499998 5.        ]
#   Resampled shape: (428, 428, 495)
#   Resize factors: [0.4485981308411215, 0.4485981308411215, 0.3878787878787879]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0006.nii.gz
#   Processing label: amos_0006.nii.gz
#   Label resampled shape: (428, 428, 495)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0006.nii.gz
#
# Processing: amos_0007.nii.gz
#   Original shape: (768, 768, 107)
#   Original voxel spacing: [0.51822919 0.51822919 5.        ]
#   Scale factors: [0.51822919 0.51822919 5.        ]
#   Resampled shape: (398, 398, 535)
#   Resize factors: [0.4824120603015075, 0.4824120603015075, 0.35887850467289717]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0007.nii.gz
#   Processing label: amos_0007.nii.gz
#   Label resampled shape: (398, 398, 535)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0007.nii.gz
#
# Processing: amos_0009.nii.gz
#   Original shape: (512, 512, 90)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 450)
#   Resize factors: [0.48, 0.48, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0009.nii.gz
#   Processing label: amos_0009.nii.gz
#   Label resampled shape: (400, 400, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0009.nii.gz
#
# Processing: amos_0010.nii.gz
#   Original shape: (512, 512, 132)
#   Original voxel spacing: [0.80800003 0.80800003 5.        ]
#   Scale factors: [0.80800003 0.80800003 5.        ]
#   Resampled shape: (414, 414, 660)
#   Resize factors: [0.463768115942029, 0.463768115942029, 0.2909090909090909]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0010.nii.gz
#   Processing label: amos_0010.nii.gz
#   Label resampled shape: (414, 414, 660)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0010.nii.gz
#
# Processing: amos_0011.nii.gz
#   Original shape: (512, 512, 92)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 460)
#   Resize factors: [0.48, 0.48, 0.41739130434782606]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0011.nii.gz
#   Processing label: amos_0011.nii.gz
#   Label resampled shape: (400, 400, 460)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0011.nii.gz
#
# Processing: amos_0014.nii.gz
#   Original shape: (512, 512, 93)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 465)
#   Resize factors: [0.48, 0.48, 0.4129032258064516]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0014.nii.gz
#   Processing label: amos_0014.nii.gz
#   Label resampled shape: (400, 400, 465)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0014.nii.gz
#
# Processing: amos_0015.nii.gz
#   Original shape: (768, 768, 103)
#   Original voxel spacing: [0.64973956 0.64973956 5.        ]
#   Scale factors: [0.64973956 0.64973956 5.        ]
#   Resampled shape: (499, 499, 515)
#   Resize factors: [0.3847695390781563, 0.3847695390781563, 0.37281553398058254]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0015.nii.gz
#   Processing label: amos_0015.nii.gz
#   Label resampled shape: (499, 499, 515)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0015.nii.gz
#
# Processing: amos_0016.nii.gz
#   Original shape: (512, 512, 91)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 455)
#   Resize factors: [0.48, 0.48, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0016.nii.gz
#   Processing label: amos_0016.nii.gz
#   Label resampled shape: (400, 400, 455)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0016.nii.gz
#
# Processing: amos_0017.nii.gz
#   Original shape: (512, 512, 91)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 455)
#   Resize factors: [0.48, 0.48, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0017.nii.gz
#   Processing label: amos_0017.nii.gz
#   Label resampled shape: (400, 400, 455)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0017.nii.gz
#
# Processing: amos_0019.nii.gz
#   Original shape: (512, 512, 101)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 505)
#   Resize factors: [0.48, 0.48, 0.3801980198019802]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0019.nii.gz
#   Processing label: amos_0019.nii.gz
#   Label resampled shape: (400, 400, 505)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0019.nii.gz
#
# Processing: amos_0021.nii.gz
#   Original shape: (512, 512, 124)
#   Original voxel spacing: [0.89200002 0.89200002 5.        ]
#   Scale factors: [0.89200002 0.89200002 5.        ]
#   Resampled shape: (457, 457, 620)
#   Resize factors: [0.4201312910284464, 0.4201312910284464, 0.3096774193548387]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0021.nii.gz
#   Processing label: amos_0021.nii.gz
#   Label resampled shape: (457, 457, 620)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0021.nii.gz
#
# Processing: amos_0023.nii.gz
#   Original shape: (512, 512, 86)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 430)
#   Resize factors: [0.48, 0.48, 0.44651162790697674]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0023.nii.gz
#   Processing label: amos_0023.nii.gz
#   Label resampled shape: (400, 400, 430)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0023.nii.gz
#
# Processing: amos_0024.nii.gz
#   Original shape: (512, 512, 85)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 425)
#   Resize factors: [0.48, 0.48, 0.45176470588235296]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0024.nii.gz
#   Processing label: amos_0024.nii.gz
#   Label resampled shape: (400, 400, 425)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0024.nii.gz
#
# Processing: amos_0025.nii.gz
#   Original shape: (512, 512, 81)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 405)
#   Resize factors: [0.48, 0.48, 0.4740740740740741]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0025.nii.gz
#   Processing label: amos_0025.nii.gz
#   Label resampled shape: (400, 400, 405)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0025.nii.gz
#
# Processing: amos_0027.nii.gz
#   Original shape: (512, 512, 124)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 620)
#   Resize factors: [0.48, 0.48, 0.3096774193548387]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0027.nii.gz
#   Processing label: amos_0027.nii.gz
#   Label resampled shape: (400, 400, 620)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0027.nii.gz
#
# Processing: amos_0030.nii.gz
#   Original shape: (512, 512, 125)
#   Original voxel spacing: [0.90700001 0.90700001 5.        ]
#   Scale factors: [0.90700001 0.90700001 5.        ]
#   Resampled shape: (464, 464, 625)
#   Resize factors: [0.41379310344827586, 0.41379310344827586, 0.3072]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0030.nii.gz
#   Processing label: amos_0030.nii.gz
#   Label resampled shape: (464, 464, 625)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0030.nii.gz
#
# Processing: amos_0033.nii.gz
#   Original shape: (512, 512, 106)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 530)
#   Resize factors: [0.48, 0.48, 0.3622641509433962]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0033.nii.gz
#   Processing label: amos_0033.nii.gz
#   Label resampled shape: (400, 400, 530)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0033.nii.gz
#
# Processing: amos_0035.nii.gz
#   Original shape: (512, 512, 93)
#   Original voxel spacing: [0.96100003 0.96100003 5.        ]
#   Scale factors: [0.96100003 0.96100003 5.        ]
#   Resampled shape: (492, 492, 465)
#   Resize factors: [0.3902439024390244, 0.3902439024390244, 0.4129032258064516]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0035.nii.gz
#   Processing label: amos_0035.nii.gz
#   Label resampled shape: (492, 492, 465)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0035.nii.gz
#
# Processing: amos_0036.nii.gz
#   Original shape: (512, 512, 124)
#   Original voxel spacing: [0.88800001 0.88800001 5.        ]
#   Scale factors: [0.88800001 0.88800001 5.        ]
#   Resampled shape: (455, 455, 620)
#   Resize factors: [0.421978021978022, 0.421978021978022, 0.3096774193548387]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0036.nii.gz
#   Processing label: amos_0036.nii.gz
#   Label resampled shape: (455, 455, 620)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0036.nii.gz
#
# Processing: amos_0038.nii.gz
#   Original shape: (512, 512, 126)
#   Original voxel spacing: [0.78100002 0.78100002 5.        ]
#   Scale factors: [0.78100002 0.78100002 5.        ]
#   Resampled shape: (400, 400, 630)
#   Resize factors: [0.48, 0.48, 0.3047619047619048]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0038.nii.gz
#   Processing label: amos_0038.nii.gz
#   Label resampled shape: (400, 400, 630)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0038.nii.gz
#
# Processing: amos_0042.nii.gz
#   Original shape: (512, 512, 89)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 445)
#   Resize factors: [0.48, 0.48, 0.4314606741573034]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0042.nii.gz
#   Processing label: amos_0042.nii.gz
#   Label resampled shape: (400, 400, 445)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0042.nii.gz
#
# Processing: amos_0043.nii.gz
#   Original shape: (512, 512, 85)
#   Original voxel spacing: [0.84299999 0.84299999 5.        ]
#   Scale factors: [0.84299999 0.84299999 5.        ]
#   Resampled shape: (432, 432, 425)
#   Resize factors: [0.4444444444444444, 0.4444444444444444, 0.45176470588235296]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0043.nii.gz
#   Processing label: amos_0043.nii.gz
#   Label resampled shape: (432, 432, 425)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0043.nii.gz
#
# Processing: amos_0044.nii.gz
#   Original shape: (768, 768, 104)
#   Original voxel spacing: [0.5078125 0.5078125 5.       ]
#   Scale factors: [0.5078125 0.5078125 5.       ]
#   Resampled shape: (390, 390, 520)
#   Resize factors: [0.49230769230769234, 0.49230769230769234, 0.36923076923076925]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0044.nii.gz
#   Processing label: amos_0044.nii.gz
#   Label resampled shape: (390, 390, 520)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0044.nii.gz
#
# Processing: amos_0045.nii.gz
#   Original shape: (768, 768, 91)
#   Original voxel spacing: [0.65104169 0.65104169 5.        ]
#   Scale factors: [0.65104169 0.65104169 5.        ]
#   Resampled shape: (500, 500, 455)
#   Resize factors: [0.384, 0.384, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0045.nii.gz
#   Processing label: amos_0045.nii.gz
#   Label resampled shape: (500, 500, 455)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0045.nii.gz
#
# Processing: amos_0047.nii.gz
#   Original shape: (768, 768, 98)
#   Original voxel spacing: [0.58854169 0.58854169 5.        ]
#   Scale factors: [0.58854169 0.58854169 5.        ]
#   Resampled shape: (452, 452, 490)
#   Resize factors: [0.4247787610619469, 0.4247787610619469, 0.39183673469387753]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0047.nii.gz
#   Processing label: amos_0047.nii.gz
#   Label resampled shape: (452, 452, 490)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0047.nii.gz
#
# Processing: amos_0048.nii.gz
#   Original shape: (768, 768, 109)
#   Original voxel spacing: [0.64973956 0.64973956 5.        ]
#   Scale factors: [0.64973956 0.64973956 5.        ]
#   Resampled shape: (499, 499, 545)
#   Resize factors: [0.3847695390781563, 0.3847695390781563, 0.3522935779816514]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0048.nii.gz
#   Processing label: amos_0048.nii.gz
#   Label resampled shape: (499, 499, 545)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0048.nii.gz
#
# Processing: amos_0049.nii.gz
#   Original shape: (768, 768, 96)
#   Original voxel spacing: [0.5078125 0.5078125 5.       ]
#   Scale factors: [0.5078125 0.5078125 5.       ]
#   Resampled shape: (390, 390, 480)
#   Resize factors: [0.49230769230769234, 0.49230769230769234, 0.4]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0049.nii.gz
#   Processing label: amos_0049.nii.gz
#   Label resampled shape: (390, 390, 480)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0049.nii.gz
#
# Processing: amos_0050.nii.gz
#   Original shape: (768, 768, 96)
#   Original voxel spacing: [0.56640625 0.56640625 5.        ]
#   Scale factors: [0.56640625 0.56640625 5.        ]
#   Resampled shape: (435, 435, 480)
#   Resize factors: [0.4413793103448276, 0.4413793103448276, 0.4]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0050.nii.gz
#   Processing label: amos_0050.nii.gz
#   Label resampled shape: (435, 435, 480)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0050.nii.gz
#
# Processing: amos_0052.nii.gz
#   Original shape: (768, 768, 102)
#   Original voxel spacing: [0.61067706 0.61067706 5.        ]
#   Scale factors: [0.61067706 0.61067706 5.        ]
#   Resampled shape: (469, 469, 510)
#   Resize factors: [0.4093816631130064, 0.4093816631130064, 0.3764705882352941]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0052.nii.gz
#   Processing label: amos_0052.nii.gz
#   Label resampled shape: (469, 469, 510)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0052.nii.gz
#
# Processing: amos_0054.nii.gz
#   Original shape: (768, 768, 90)
#   Original voxel spacing: [0.609375 0.609375 5.      ]
#   Scale factors: [0.609375 0.609375 5.      ]
#   Resampled shape: (468, 468, 450)
#   Resize factors: [0.41025641025641024, 0.41025641025641024, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0054.nii.gz
#   Processing label: amos_0054.nii.gz
#   Label resampled shape: (468, 468, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0054.nii.gz
#
# Processing: amos_0057.nii.gz
#   Original shape: (768, 768, 87)
#   Original voxel spacing: [0.65104169 0.65104169 5.        ]
#   Scale factors: [0.65104169 0.65104169 5.        ]
#   Resampled shape: (500, 500, 435)
#   Resize factors: [0.384, 0.384, 0.4413793103448276]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0057.nii.gz
#   Processing label: amos_0057.nii.gz
#   Label resampled shape: (500, 500, 435)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0057.nii.gz
#
# Processing: amos_0058.nii.gz
#   Original shape: (768, 768, 95)
#   Original voxel spacing: [0.59895831 0.59895831 5.        ]
#   Scale factors: [0.59895831 0.59895831 5.        ]
#   Resampled shape: (460, 460, 475)
#   Resize factors: [0.41739130434782606, 0.41739130434782606, 0.40421052631578946]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0058.nii.gz
#   Processing label: amos_0058.nii.gz
#   Label resampled shape: (460, 460, 475)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0058.nii.gz
#
# Processing: amos_0059.nii.gz
#   Original shape: (512, 512, 78)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 390)
#   Resize factors: [0.48, 0.48, 0.49230769230769234]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0059.nii.gz
#   Processing label: amos_0059.nii.gz
#   Label resampled shape: (400, 400, 390)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0059.nii.gz
#
# Processing: amos_0060.nii.gz
#   Original shape: (768, 768, 112)
#   Original voxel spacing: [0.52734375 0.52734375 5.        ]
#   Scale factors: [0.52734375 0.52734375 5.        ]
#   Resampled shape: (405, 405, 560)
#   Resize factors: [0.4740740740740741, 0.4740740740740741, 0.34285714285714286]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0060.nii.gz
#   Processing label: amos_0060.nii.gz
#   Label resampled shape: (405, 405, 560)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0060.nii.gz
#
# Processing: amos_0064.nii.gz
#   Original shape: (512, 512, 89)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 445)
#   Resize factors: [0.48, 0.48, 0.4314606741573034]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0064.nii.gz
#   Processing label: amos_0064.nii.gz
#   Label resampled shape: (400, 400, 445)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0064.nii.gz
#
# Processing: amos_0066.nii.gz
#   Original shape: (512, 512, 88)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 440)
#   Resize factors: [0.48, 0.48, 0.43636363636363634]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0066.nii.gz
#   Processing label: amos_0066.nii.gz
#   Label resampled shape: (400, 400, 440)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0066.nii.gz
#
# Processing: amos_0067.nii.gz
#   Original shape: (512, 512, 122)
#   Original voxel spacing: [0.85399997 0.85399997 5.        ]
#   Scale factors: [0.85399997 0.85399997 5.        ]
#   Resampled shape: (437, 437, 610)
#   Resize factors: [0.43935926773455375, 0.43935926773455375, 0.31475409836065577]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0067.nii.gz
#   Processing label: amos_0067.nii.gz
#   Label resampled shape: (437, 437, 610)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0067.nii.gz
#
# Processing: amos_0069.nii.gz
#   Original shape: (512, 512, 98)
#   Original voxel spacing: [0.801 0.801 5.   ]
#   Scale factors: [0.801 0.801 5.   ]
#   Resampled shape: (410, 410, 490)
#   Resize factors: [0.4682926829268293, 0.4682926829268293, 0.39183673469387753]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0069.nii.gz
#   Processing label: amos_0069.nii.gz
#   Label resampled shape: (410, 410, 490)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0069.nii.gz
#
# Processing: amos_0071.nii.gz
#   Original shape: (512, 512, 135)
#   Original voxel spacing: [0.83499998 0.83499998 5.        ]
#   Scale factors: [0.83499998 0.83499998 5.        ]
#   Resampled shape: (428, 428, 675)
#   Resize factors: [0.4485981308411215, 0.4485981308411215, 0.28444444444444444]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0071.nii.gz
#   Processing label: amos_0071.nii.gz
#   Label resampled shape: (428, 428, 675)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0071.nii.gz
#
# Processing: amos_0072.nii.gz
#   Original shape: (768, 768, 90)
#   Original voxel spacing: [0.58854169 0.58854169 5.        ]
#   Scale factors: [0.58854169 0.58854169 5.        ]
#   Resampled shape: (452, 452, 450)
#   Resize factors: [0.4247787610619469, 0.4247787610619469, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0072.nii.gz
#   Processing label: amos_0072.nii.gz
#   Label resampled shape: (452, 452, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0072.nii.gz
#
# Processing: amos_0075.nii.gz
#   Original shape: (512, 512, 84)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 420)
#   Resize factors: [0.48, 0.48, 0.45714285714285713]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0075.nii.gz
#   Processing label: amos_0075.nii.gz
#   Label resampled shape: (400, 400, 420)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0075.nii.gz
#
# Processing: amos_0076.nii.gz
#   Original shape: (768, 768, 82)
#   Original voxel spacing: [0.48307291 0.48307291 5.        ]
#   Scale factors: [0.48307291 0.48307291 5.        ]
#   Resampled shape: (371, 371, 410)
#   Resize factors: [0.5175202156334232, 0.5175202156334232, 0.4682926829268293]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0076.nii.gz
#   Processing label: amos_0076.nii.gz
#   Label resampled shape: (371, 371, 410)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0076.nii.gz
#
# Processing: amos_0077.nii.gz
#   Original shape: (768, 768, 102)
#   Original voxel spacing: [0.65104169 0.65104169 5.        ]
#   Scale factors: [0.65104169 0.65104169 5.        ]
#   Resampled shape: (500, 500, 510)
#   Resize factors: [0.384, 0.384, 0.3764705882352941]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0077.nii.gz
#   Processing label: amos_0077.nii.gz
#   Label resampled shape: (500, 500, 510)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0077.nii.gz
#
# Processing: amos_0078.nii.gz
#   Original shape: (512, 512, 92)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 460)
#   Resize factors: [0.48, 0.48, 0.41739130434782606]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0078.nii.gz
#   Processing label: amos_0078.nii.gz
#   Label resampled shape: (400, 400, 460)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0078.nii.gz
#
# Processing: amos_0079.nii.gz
#   Original shape: (768, 768, 81)
#   Original voxel spacing: [0.53515625 0.53515625 5.        ]
#   Scale factors: [0.53515625 0.53515625 5.        ]
#   Resampled shape: (411, 411, 405)
#   Resize factors: [0.46715328467153283, 0.46715328467153283, 0.4740740740740741]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0079.nii.gz
#   Processing label: amos_0079.nii.gz
#   Label resampled shape: (411, 411, 405)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0079.nii.gz
#
# Processing: amos_0081.nii.gz
#   Original shape: (768, 768, 93)
#   Original voxel spacing: [0.55338544 0.55338544 5.        ]
#   Scale factors: [0.55338544 0.55338544 5.        ]
#   Resampled shape: (425, 425, 465)
#   Resize factors: [0.45176470588235296, 0.45176470588235296, 0.4129032258064516]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0081.nii.gz
#   Processing label: amos_0081.nii.gz
#   Label resampled shape: (425, 425, 465)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0081.nii.gz
#
# Processing: amos_0083.nii.gz
#   Original shape: (512, 512, 100)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 500)
#   Resize factors: [0.48, 0.48, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0083.nii.gz
#   Processing label: amos_0083.nii.gz
#   Label resampled shape: (400, 400, 500)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0083.nii.gz
#
# Processing: amos_0084.nii.gz
#   Original shape: (512, 512, 84)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 420)
#   Resize factors: [0.48, 0.48, 0.45714285714285713]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0084.nii.gz
#   Processing label: amos_0084.nii.gz
#   Label resampled shape: (400, 400, 420)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0084.nii.gz
#
# Processing: amos_0086.nii.gz
#   Original shape: (512, 512, 80)
#   Original voxel spacing: [0.85799998 0.85799998 5.        ]
#   Scale factors: [0.85799998 0.85799998 5.        ]
#   Resampled shape: (439, 439, 400)
#   Resize factors: [0.43735763097949887, 0.43735763097949887, 0.48]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0086.nii.gz
#   Processing label: amos_0086.nii.gz
#   Label resampled shape: (439, 439, 400)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0086.nii.gz
#
# Processing: amos_0088.nii.gz
#   Original shape: (512, 512, 68)
#   Original voxel spacing: [0.74699998 0.74699998 5.        ]
#   Scale factors: [0.74699998 0.74699998 5.        ]
#   Resampled shape: (382, 382, 340)
#   Resize factors: [0.5026178010471204, 0.5026178010471204, 0.5647058823529412]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0088.nii.gz
#   Processing label: amos_0088.nii.gz
#   Label resampled shape: (382, 382, 340)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0088.nii.gz
#
# Processing: amos_0089.nii.gz
#   Original shape: (512, 512, 116)
#   Original voxel spacing: [0.94599998 0.94599998 5.        ]
#   Scale factors: [0.94599998 0.94599998 5.        ]
#   Resampled shape: (484, 484, 580)
#   Resize factors: [0.39669421487603307, 0.39669421487603307, 0.3310344827586207]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0089.nii.gz
#   Processing label: amos_0089.nii.gz
#   Label resampled shape: (484, 484, 580)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0089.nii.gz
#
# Processing: amos_0092.nii.gz
#   Original shape: (512, 512, 132)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 660)
#   Resize factors: [0.48, 0.48, 0.2909090909090909]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0092.nii.gz
#   Processing label: amos_0092.nii.gz
#   Label resampled shape: (400, 400, 660)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0092.nii.gz
#
# Processing: amos_0094.nii.gz
#   Original shape: (512, 512, 91)
#   Original voxel spacing: [0.824 0.824 5.   ]
#   Scale factors: [0.824 0.824 5.   ]
#   Resampled shape: (422, 422, 455)
#   Resize factors: [0.4549763033175355, 0.4549763033175355, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0094.nii.gz
#   Processing label: amos_0094.nii.gz
#   Label resampled shape: (422, 422, 455)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0094.nii.gz
#
# Processing: amos_0097.nii.gz
#   Original shape: (512, 512, 126)
#   Original voxel spacing: [1.06799996 1.06799996 5.        ]
#   Scale factors: [1.06799996 1.06799996 5.        ]
#   Resampled shape: (547, 547, 630)
#   Resize factors: [0.3510054844606947, 0.3510054844606947, 0.3047619047619048]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0097.nii.gz
#   Processing label: amos_0097.nii.gz
#   Label resampled shape: (547, 547, 630)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0097.nii.gz
#
# Processing: amos_0098.nii.gz
#   Original shape: (512, 512, 97)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 485)
#   Resize factors: [0.48, 0.48, 0.3958762886597938]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0098.nii.gz
#   Processing label: amos_0098.nii.gz
#   Label resampled shape: (400, 400, 485)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0098.nii.gz
#
# Processing: amos_0099.nii.gz
#   Original shape: (768, 768, 99)
#   Original voxel spacing: [0.65104169 0.65104169 5.        ]
#   Scale factors: [0.65104169 0.65104169 5.        ]
#   Resampled shape: (500, 500, 495)
#   Resize factors: [0.384, 0.384, 0.3878787878787879]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0099.nii.gz
#   Processing label: amos_0099.nii.gz
#   Label resampled shape: (500, 500, 495)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0099.nii.gz
#
# Processing: amos_0102.nii.gz
#   Original shape: (768, 768, 101)
#   Original voxel spacing: [0.63151044 0.63151044 5.        ]
#   Scale factors: [0.63151044 0.63151044 5.        ]
#   Resampled shape: (485, 485, 505)
#   Resize factors: [0.3958762886597938, 0.3958762886597938, 0.3801980198019802]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0102.nii.gz
#   Processing label: amos_0102.nii.gz
#   Label resampled shape: (485, 485, 505)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0102.nii.gz
#
# Processing: amos_0103.nii.gz
#   Original shape: (768, 768, 81)
#   Original voxel spacing: [0.5390625 0.5390625 5.       ]
#   Scale factors: [0.5390625 0.5390625 5.       ]
#   Resampled shape: (414, 414, 405)
#   Resize factors: [0.463768115942029, 0.463768115942029, 0.4740740740740741]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0103.nii.gz
#   Processing label: amos_0103.nii.gz
#   Label resampled shape: (414, 414, 405)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0103.nii.gz
#
# Processing: amos_0104.nii.gz
#   Original shape: (512, 512, 88)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 440)
#   Resize factors: [0.48, 0.48, 0.43636363636363634]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0104.nii.gz
#   Processing label: amos_0104.nii.gz
#   Label resampled shape: (400, 400, 440)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0104.nii.gz
#
# Processing: amos_0105.nii.gz
#   Original shape: (768, 768, 95)
#   Original voxel spacing: [0.57682294 0.57682294 5.        ]
#   Scale factors: [0.57682294 0.57682294 5.        ]
#   Resampled shape: (443, 443, 475)
#   Resize factors: [0.43340857787810383, 0.43340857787810383, 0.40421052631578946]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0105.nii.gz
#   Processing label: amos_0105.nii.gz
#   Label resampled shape: (443, 443, 475)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0105.nii.gz
#
# Processing: amos_0109.nii.gz
#   Original shape: (768, 768, 90)
#   Original voxel spacing: [0.61979169 0.61979169 5.        ]
#   Scale factors: [0.61979169 0.61979169 5.        ]
#   Resampled shape: (476, 476, 450)
#   Resize factors: [0.40336134453781514, 0.40336134453781514, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0109.nii.gz
#   Processing label: amos_0109.nii.gz
#   Label resampled shape: (476, 476, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0109.nii.gz
#
# Processing: amos_0110.nii.gz
#   Original shape: (512, 512, 120)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 600)
#   Resize factors: [0.48, 0.48, 0.32]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0110.nii.gz
#   Processing label: amos_0110.nii.gz
#   Label resampled shape: (400, 400, 600)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0110.nii.gz
#
# Processing: amos_0111.nii.gz
#   Original shape: (512, 512, 107)
#   Original voxel spacing: [0.78200001 0.78200001 5.        ]
#   Scale factors: [0.78200001 0.78200001 5.        ]
#   Resampled shape: (400, 400, 535)
#   Resize factors: [0.48, 0.48, 0.35887850467289717]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0111.nii.gz
#   Processing label: amos_0111.nii.gz
#   Label resampled shape: (400, 400, 535)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0111.nii.gz
#
# Processing: amos_0113.nii.gz
#   Original shape: (768, 768, 91)
#   Original voxel spacing: [0.64713544 0.64713544 5.        ]
#   Scale factors: [0.64713544 0.64713544 5.        ]
#   Resampled shape: (497, 497, 455)
#   Resize factors: [0.386317907444668, 0.386317907444668, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0113.nii.gz
#   Processing label: amos_0113.nii.gz
# ...
#   Resize factors: [0.41113490364025695, 0.41113490364025695, 0.384]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0379.nii.gz
#   Processing label: amos_0379.nii.gz
#   Label resampled shape: (467, 467, 500)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0379.nii.gz
#
# Processing: amos_0380.nii.gz
#   Original shape: (768, 768, 93)
#   Original voxel spacing: [0.60677081 0.60677081 5.        ]
#   Scale factors: [0.60677081 0.60677081 5.        ]
#   Resampled shape: (466, 466, 465)
#   Resize factors: [0.41201716738197425, 0.41201716738197425, 0.4129032258064516]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0380.nii.gz
#   Processing label: amos_0380.nii.gz
#   Label resampled shape: (466, 466, 465)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0380.nii.gz
#
# Processing: amos_0381.nii.gz
#   Original shape: (768, 768, 83)
#   Original voxel spacing: [0.64583331 0.64583331 5.        ]
#   Scale factors: [0.64583331 0.64583331 5.        ]
#   Resampled shape: (496, 496, 415)
#   Resize factors: [0.3870967741935484, 0.3870967741935484, 0.46265060240963857]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0381.nii.gz
#   Processing label: amos_0381.nii.gz
#   Label resampled shape: (496, 496, 415)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0381.nii.gz
#
# Processing: amos_0383.nii.gz
#   Original shape: (768, 768, 97)
#   Original voxel spacing: [0.60546875 0.60546875 5.        ]
#   Scale factors: [0.60546875 0.60546875 5.        ]
#   Resampled shape: (465, 465, 485)
#   Resize factors: [0.4129032258064516, 0.4129032258064516, 0.3958762886597938]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0383.nii.gz
#   Processing label: amos_0383.nii.gz
#   Label resampled shape: (465, 465, 485)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0383.nii.gz
#
# Processing: amos_0384.nii.gz
#   Original shape: (768, 768, 94)
#   Original voxel spacing: [0.46223959 0.46223959 5.        ]
#   Scale factors: [0.46223959 0.46223959 5.        ]
#   Resampled shape: (355, 355, 470)
#   Resize factors: [0.5408450704225352, 0.5408450704225352, 0.4085106382978723]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0384.nii.gz
#   Processing label: amos_0384.nii.gz
#   Label resampled shape: (355, 355, 470)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0384.nii.gz
#
# Processing: amos_0387.nii.gz
#   Original shape: (768, 768, 105)
#   Original voxel spacing: [0.58203125 0.58203125 5.        ]
#   Scale factors: [0.58203125 0.58203125 5.        ]
#   Resampled shape: (447, 447, 525)
#   Resize factors: [0.42953020134228187, 0.42953020134228187, 0.3657142857142857]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0387.nii.gz
#   Processing label: amos_0387.nii.gz
#   Label resampled shape: (447, 447, 525)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0387.nii.gz
#
# Processing: amos_0388.nii.gz
#   Original shape: (768, 768, 82)
#   Original voxel spacing: [0.48177084 0.48177084 5.        ]
#   Scale factors: [0.48177084 0.48177084 5.        ]
#   Resampled shape: (370, 370, 410)
#   Resize factors: [0.518918918918919, 0.518918918918919, 0.4682926829268293]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0388.nii.gz
#   Processing label: amos_0388.nii.gz
#   Label resampled shape: (370, 370, 410)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0388.nii.gz
#
# Processing: amos_0390.nii.gz
#   Original shape: (768, 768, 99)
#   Original voxel spacing: [0.62109375 0.62109375 5.        ]
#   Scale factors: [0.62109375 0.62109375 5.        ]
#   Resampled shape: (477, 477, 495)
#   Resize factors: [0.4025157232704403, 0.4025157232704403, 0.3878787878787879]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0390.nii.gz
#   Processing label: amos_0390.nii.gz
#   Label resampled shape: (477, 477, 495)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0390.nii.gz
#
# Processing: amos_0391.nii.gz
#   Original shape: (512, 512, 83)
#   Original voxel spacing: [0.97265625 0.97265625 5.        ]
#   Scale factors: [0.97265625 0.97265625 5.        ]
#   Resampled shape: (498, 498, 415)
#   Resize factors: [0.3855421686746988, 0.3855421686746988, 0.46265060240963857]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0391.nii.gz
#   Processing label: amos_0391.nii.gz
#   Label resampled shape: (498, 498, 415)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0391.nii.gz
#
# Processing: amos_0392.nii.gz
#   Original shape: (768, 768, 85)
#   Original voxel spacing: [0.53645831 0.53645831 5.        ]
#   Scale factors: [0.53645831 0.53645831 5.        ]
#   Resampled shape: (412, 412, 425)
#   Resize factors: [0.46601941747572817, 0.46601941747572817, 0.45176470588235296]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0392.nii.gz
#   Processing label: amos_0392.nii.gz
#   Label resampled shape: (412, 412, 425)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0392.nii.gz
#
# Processing: amos_0395.nii.gz
#   Original shape: (768, 768, 83)
#   Original voxel spacing: [0.46223959 0.46223959 5.        ]
#   Scale factors: [0.46223959 0.46223959 5.        ]
#   Resampled shape: (355, 355, 415)
#   Resize factors: [0.5408450704225352, 0.5408450704225352, 0.46265060240963857]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0395.nii.gz
#   Processing label: amos_0395.nii.gz
#   Label resampled shape: (355, 355, 415)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0395.nii.gz
#
# Processing: amos_0396.nii.gz
#   Original shape: (768, 768, 86)
#   Original voxel spacing: [0.64322919 0.64322919 5.        ]
#   Scale factors: [0.64322919 0.64322919 5.        ]
#   Resampled shape: (494, 494, 430)
#   Resize factors: [0.38866396761133604, 0.38866396761133604, 0.44651162790697674]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0396.nii.gz
#   Processing label: amos_0396.nii.gz
#   Label resampled shape: (494, 494, 430)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0396.nii.gz
#
# Processing: amos_0398.nii.gz
#   Original shape: (768, 768, 82)
#   Original voxel spacing: [0.62760419 0.62760419 5.        ]
#   Scale factors: [0.62760419 0.62760419 5.        ]
#   Resampled shape: (482, 482, 410)
#   Resize factors: [0.3983402489626556, 0.3983402489626556, 0.4682926829268293]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0398.nii.gz
#   Processing label: amos_0398.nii.gz
#   Label resampled shape: (482, 482, 410)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0398.nii.gz
#
# Processing: amos_0400.nii.gz
#   Original shape: (768, 768, 79)
#   Original voxel spacing: [0.46744791 0.46744791 5.        ]
#   Scale factors: [0.46744791 0.46744791 5.        ]
#   Resampled shape: (359, 359, 395)
#   Resize factors: [0.5348189415041783, 0.5348189415041783, 0.4860759493670886]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0400.nii.gz
#   Processing label: amos_0400.nii.gz
#   Label resampled shape: (359, 359, 395)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0400.nii.gz
#
# Processing: amos_0401.nii.gz
#   Original shape: (768, 768, 91)
#   Original voxel spacing: [0.52473956 0.52473956 5.        ]
#   Scale factors: [0.52473956 0.52473956 5.        ]
#   Resampled shape: (403, 403, 455)
#   Resize factors: [0.47642679900744417, 0.47642679900744417, 0.421978021978022]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0401.nii.gz
#   Processing label: amos_0401.nii.gz
#   Label resampled shape: (403, 403, 455)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0401.nii.gz
#
# Processing: amos_0402.nii.gz
#   Original shape: (768, 768, 93)
#   Original voxel spacing: [0.55208331 0.55208331 5.        ]
#   Scale factors: [0.55208331 0.55208331 5.        ]
#   Resampled shape: (424, 424, 465)
#   Resize factors: [0.4528301886792453, 0.4528301886792453, 0.4129032258064516]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0402.nii.gz
#   Processing label: amos_0402.nii.gz
#   Label resampled shape: (424, 424, 465)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0402.nii.gz
#
# Processing: amos_0403.nii.gz
#   Original shape: (768, 768, 87)
#   Original voxel spacing: [0.5625 0.5625 5.    ]
#   Scale factors: [0.5625 0.5625 5.    ]
#   Resampled shape: (432, 432, 435)
#   Resize factors: [0.4444444444444444, 0.4444444444444444, 0.4413793103448276]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0403.nii.gz
#   Processing label: amos_0403.nii.gz
#   Label resampled shape: (432, 432, 435)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0403.nii.gz
#
# Processing: amos_0404.nii.gz
#   Original shape: (768, 768, 84)
#   Original voxel spacing: [0.53515625 0.53515625 5.        ]
#   Scale factors: [0.53515625 0.53515625 5.        ]
#   Resampled shape: (411, 411, 420)
#   Resize factors: [0.46715328467153283, 0.46715328467153283, 0.45714285714285713]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0404.nii.gz
#   Processing label: amos_0404.nii.gz
#   Label resampled shape: (411, 411, 420)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0404.nii.gz
#
# Processing: amos_0405.nii.gz
#   Original shape: (768, 768, 90)
#   Original voxel spacing: [0.58854169 0.58854169 5.        ]
#   Scale factors: [0.58854169 0.58854169 5.        ]
#   Resampled shape: (452, 452, 450)
#   Resize factors: [0.4247787610619469, 0.4247787610619469, 0.4266666666666667]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0405.nii.gz
#   Processing label: amos_0405.nii.gz
#   Label resampled shape: (452, 452, 450)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0405.nii.gz
#
# Processing: amos_0406.nii.gz
#   Original shape: (768, 768, 82)
#   Original voxel spacing: [0.55598956 0.55598956 5.        ]
#   Scale factors: [0.55598956 0.55598956 5.        ]
#   Resampled shape: (427, 427, 410)
#   Resize factors: [0.4496487119437939, 0.4496487119437939, 0.4682926829268293]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0406.nii.gz
#   Processing label: amos_0406.nii.gz
#   Label resampled shape: (427, 427, 410)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0406.nii.gz
#
# Processing: amos_0408.nii.gz
#   Original shape: (768, 768, 104)
#   Original voxel spacing: [0.61458331 0.61458331 5.        ]
#   Scale factors: [0.61458331 0.61458331 5.        ]
#   Resampled shape: (472, 472, 520)
#   Resize factors: [0.4067796610169492, 0.4067796610169492, 0.36923076923076925]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0408.nii.gz
#   Processing label: amos_0408.nii.gz
#   Label resampled shape: (472, 472, 520)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0408.nii.gz
#
# Processing: amos_0410.nii.gz
#   Original shape: (768, 768, 107)
#   Original voxel spacing: [0.58333331 0.58333331 5.        ]
#   Scale factors: [0.58333331 0.58333331 5.        ]
#   Resampled shape: (448, 448, 535)
#   Resize factors: [0.42857142857142855, 0.42857142857142855, 0.35887850467289717]
#   Final image shape: (192, 192, 192)
#   Saved image to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/images/amos_0410.nii.gz
#   Processing label: amos_0410.nii.gz
#   Label resampled shape: (448, 448, 535)
#   Final label shape: (192, 192, 192)
#   Saved label to: /Users/fransiskusbudi/UoE/Dissertation/multimodal_segmentation_project/datasets/resampled/train/amos_ct/labels/amos_0410.nii.gz
#
# ✅ All CT images and labels have been processed.
